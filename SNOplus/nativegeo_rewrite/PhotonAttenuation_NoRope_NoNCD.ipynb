# %% [markdown]
# ## Attenuation with vessel+belly plates (no ropes or NCD anchors)

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
import collections
# %matplotlib inline 
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import geo_studies, rat_misc
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available

# %%
reload(geo_studies)
# Out:
# <module 'geo_studies' from '/home/jp/projects/snoplus/python_modules/geo_studies.pyc'>

# %%
ratreader = None

# %%
# Opening the file
infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
infile_dir += 'ref_norope_noanchors'
infile_name = 'pbomb380.root'
ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
# Out:
# No ratreader file. Opening it for the first time

# %%
reference = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)

# %%
# Opening the file
infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
infile_dir += 'jpmod_norope_noanchors'
infile_name = 'pbomb380.root'
ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
# Out:
# No ratreader file. Opening it for the first time

# %%
jpmod = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)

# %% [raw]
# # Opening the file
# infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
# infile_dir += 'jpmod_norope_noanchors_noplates_v2'
# infile_name = 'pbomb380.root'
# ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
# jpmod2 = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)

# %%
geo_studies.compareTracking(set_list = [reference, jpmod])
# Out:
# Difference in photons produced -284 1127.85593052
# /home/jp/projects/python_tools/jp_mpl.py:85: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if yerror == None:

# %%
cosz_list = np.linspace(-1, 1, 8)
for i in range(len(cosz_list)-1):
    costheta_range = [cosz_list[i],cosz_list[i+1]]
    print '\nRange ', costheta_range
    geo_studies.compareTracking(set_list = [reference, jpmod],
                               costheta_range = costheta_range)
# Out:
# Range  [-1.0, -0.7142857142857143]
# Difference in photons produced 830 426.51377469
#
# Range  [-0.7142857142857143, -0.4285714285714286]
# Difference in photons produced -141 426.124394983
#
# Range  [-0.4285714285714286, -0.1428571428571429]
# Difference in photons produced -126 426.36838532
#
# Range  [-0.1428571428571429, 0.14285714285714279]
# Difference in photons produced 315 426.359003658
#
# Range  [0.14285714285714279, 0.42857142857142838]
# Difference in photons produced -586 426.258137752
#
# Range  [0.42857142857142838, 0.71428571428571419]
# Difference in photons produced -476 425.84504224
# /home/jp/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Range  [0.71428571428571419, 1.0]
# Difference in photons produced -100 426.557147402
