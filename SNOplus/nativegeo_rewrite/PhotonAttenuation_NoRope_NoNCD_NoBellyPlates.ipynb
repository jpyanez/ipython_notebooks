# %% [markdown]
# ## Attenuation stripped of complex objects

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
import collections
# %matplotlib inline 
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import geo_studies, rat_misc
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available

# %%
reload(geo_studies)
# Out:
# <module 'geo_studies' from '/home/jp/projects/snoplus/python_modules/geo_studies.py'>

# %%
ratreader = None

# %%
# Opening the file
infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
infile_dir += 'ref_norope_noanchors_noplates'
infile_name = 'pbomb380.root'
ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
# Out:
# No ratreader file. Opening it for the first time

# %%
reference = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)

# %%
# Opening the file
infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
infile_dir += 'jpmod_norope_noanchors_noplates'
infile_name = 'pbomb380.root'
ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
# Out:
# No ratreader file. Opening it for the first time

# %%
jpmod = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)

# %%
# Opening the file
infile_dir = '/home/jp/projects/snoplus/rundir/nativegeo_rewrite/'
infile_dir += 'jpmod_norope_noanchors_noplates_v2'
infile_name = 'pbomb380.root'
ratreader = rat_misc.openRat(infile_dir, infile_name, ratreader)
jpmod2 = geo_studies.doRead(ratreader=ratreader, max_photons = 10000000)
# Out:
# No ratreader file. Opening it for the first time

# %%
geo_studies.compareTracking(set_list = [reference, jpmod, jpmod2])
# Out:
# Difference in photons produced 756 1127.79829757
# Difference in photons produced 997 1127.79829757

# %%
cosz_list = np.linspace(-1, 1, 8)
for i in range(len(cosz_list)-1):
    costheta_range = [cosz_list[i],cosz_list[i+1]]
    print '\nRange ', costheta_range
    geo_studies.compareTracking(set_list = [reference, jpmod, jpmod2],
                               costheta_range = costheta_range)
# Out:
# Range  [-1.0, -0.7142857142857143]
# Difference in photons produced 402 426.411772821
# Difference in photons produced 752 426.411772821
#
# Range  [-0.7142857142857143, -0.4285714285714286]
# Difference in photons produced -479 425.684155214
# Difference in photons produced 604 425.684155214
#
# Range  [-0.4285714285714286, -0.1428571428571429]
# Difference in photons produced 1016 426.480949164
# Difference in photons produced -229 426.480949164
#
# Range  [-0.1428571428571429, 0.14285714285714279]
# Difference in photons produced -42 426.846576653
# Difference in photons produced 227 426.846576653
#
# Range  [0.14285714285714279, 0.42857142857142838]
# Difference in photons produced -90 426.328511831
# Difference in photons produced -215 426.328511831
#
# Range  [0.42857142857142838, 0.71428571428571419]
# Difference in photons produced -257 426.070416715
# Difference in photons produced -370 426.070416715
#
# Range  [0.71428571428571419, 1.0]
# Difference in photons produced 206 426.050466494
# Difference in photons produced 228 426.050466494
