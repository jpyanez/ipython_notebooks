# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 
#sys.path.append('/home/jp/projects/python_tools')
import jp_mpl as jplot
import rat

# %%
infile_name = '/home/jpyanez/dmytro_5mev_full.root'

# %%
try:
    ratreader.close()
    print 'Closing file before reopenning'
except:
    print 'No ratreader file. Opening it for the first time'
ratreader = rat.dsreader(os.path.join(infile_name))
# Out:
# Closing file before reopenning

# %%
ds, run = ratreader.next()

# %%
mc = ds.GetMC()

# %%
track_count = mc.GetMCTrackCount()

# %%
print track_count
# Out:
# 1935

# %%
i = 1
track = mc.GetMCTrack(i)

# %%
print track.GetPDGCode()
print '11, that is an electron'
# Out:
# 11
# 11, that is an electron

# %%
print 'Number of steps'
track.GetMCTrackStepCount()
# Out:
# Number of steps
# 473L

# %%
positions = np.zeros([track.GetMCTrackStepCount(),3])
for istep in range(track.GetMCTrackStepCount()):
    mystep = track.GetMCTrackStep(istep)
    positions[istep,:]  = position = mystep.GetPosition()

# %%
positions
# Out:
# array([[-2990.15429688,  1208.21801758,   551.57861328],
#        [-2990.10888672,  1208.2088623 ,   551.59997559],
#        [-2990.0637207 ,  1208.1973877 ,   551.62115479],
#        ...,
#        [-2969.64526367,  1205.35180664,   548.9442749 ],
#        [-2969.82910156,  1205.30041504,   549.06939697],
#        [-2970.02978516,  1205.41967773,   549.1239624 ]])

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(positions[:2,0],positions[:2,1],positions[:2,2], 'x')
ax.plot(positions[:,0], positions[:,1], positions[:,2])
