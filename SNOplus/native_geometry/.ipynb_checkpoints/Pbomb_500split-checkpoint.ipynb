# %% [markdown]
# ## Testing Aksel's "native" geometry<br> Photon bomb at 500 nm<br> Using labppo and water

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
sys.path.append('/home/jp/projects/snoplus/snoing/install/rat-dev/example/pyroot')
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import lowlevel_stats
reload(lowlevel_stats)
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available
# TClass::TClass:0: RuntimeWarning: no dictionary for class RAT::DU::ShadowingCalculator is available
# <module 'lowlevel_stats' from '/home/jp/projects/snoplus/python_modules/lowlevel_stats.pyc'>

# %%
outdir = '/home/jp/Dropbox/workflowy/snoplus/nativegeo_validation'

# %%
# Reading fcn
def readFile(one_dirname, fname):
    if one_dirname in data.keys():
        print 'This directory is already inside:', one_dirname
        return
    else:
        data[one_dirname] = {}
        
    file_name = os.path.join(basedir, one_dirname, fname)

    data[one_dirname]['nhit'], data[one_dirname]['qtot'] = \
        lowlevel_stats.getHitRegions(file_name)

    return

# %%
# Initialize the data dictionary
data = {}

# %%
basedir = '/home/jp/projects/snoplus/rundir/nativegeo_verification/pbomb'

# %%
mycolors = ['b','r','g','m','c', 'y', '0.6']
def plotComparison(datasets = [], datakey = '', scale_factor = [], 
                   labels = [], figname = '', xaxis = np.arange(0, 100, 2),
                   xlabel = 'Nhits', ylabel = 'Entries', verbose=False):

    if len(scale_factor) == 0:
        scale_factor = [1.]*len(datasets)
    if len(labels) == 0:
        labels = datasets


    # Loop over the different levels
    for k, level in enumerate(['top','middle','bottom']):
        # Reading each of the files one by one
        if verbose:        print '\n****', level , '*****'
        nbins = []
        myfig = plt.figure(figsize=(8,5))    
        
        for i, one_set in enumerate(datasets):
            n, x = np.histogram(data[one_set][datakey][:,k], xaxis)
            nbins.append(n)

            if verbose:
                print '\n',labels[i]

                print 'SUM ', data[one_set][datakey][:,k].sum()*scale_factor[i]
                print 'Mean ', data[one_set][datakey][:,k].mean()
                print 'Std  ', data[one_set][datakey][:,k].std()

            jplot.unfilledBar(xaxis, nbins[-1]*scale_factor[i], 
                                  color = mycolors[i])
            jplot.errorMark(xaxis, nbins[-1]*scale_factor[i], 
                            error=np.sqrt(nbins[-1])*scale_factor[i], color=mycolors[i],
                            label =labels[i] + ' ' + \
                                '\nmean=' + "%.2f" % data[one_set][datakey][:,k].mean() +\
                                '\nstd=' + "%.2f" % data[one_set][datakey][:,k].std()) 

        plt.title(level)



        plt.xlabel(xlabel)
        plt.ylabel(ylabel)

        #plt.ylim([0,])
        plt.legend(loc=0,ncol=1)
        if len(figname) > 0:
            myfig.savefig(os.path.join(outdir, figname + '_' + level + '.png'), dpi=300)

# %% [markdown]
# ### Using photon bomb

# %% [markdown]
# #### Scintillator comparisons

# %%
readFile('snoplusnative','pbomb.root')

# %%
readFile('snoplusnative_noropes','pbomb.root')

# %%
readFile('snoplus_simple','pbomb.root')

# %%
readFile('snoplus','pbomb.root')

# %%
readFile('snoplus_noropes','pbomb.root')

# %%
readFile('snoplusnative_noropes_jpmod','pbomb.root')

# %%
plotComparison(datasets = ['snoplus_noropes',  
                           'snoplus'],
               datakey = 'nhit',
               scale_factor = [1.,1.],
               figname = 'PBomb_nhit_reference_noropes',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries')

# %%
plotComparison(datasets = ['snoplus_simple',  
                           'snoplus'],
               datakey = 'nhit',
               scale_factor = [1.,10.],
               figname = 'PBomb_nhit_reference',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries')

# %%
plotComparison(datasets = ['snoplusnative_noropes',  
                           'snoplusnative'],
               datakey = 'nhit',
               scale_factor = [10.,1.],
               figname = 'PBomb_nhit_native_noropes',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries')

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplus',
                           'snoplusnative', 'snoplusnative_noropes'],
               datakey = 'nhit',
               scale_factor = [1.,10.,1., 10.],
               figname = 'PBomb_nhit_native_vs_simple',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries')

# %%
plotComparison(datasets = [ 'snoplusnative','snoplusnative_noropes',
                          'snoplusnative_noropes_jpmod'],
               datakey = 'nhit',
               scale_factor = [1.,10.,10.],
               figname = 'PBomb_nhit_native_vs_jpmod',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries')

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplusnative', 
                           'snoplus', 'snoplusnative_noropes'],
              datakey = 'qtot',
               scale_factor = [1.,1.,10., 10.],
              figname = 'PBomb_qtot_native_vs_simple',
              xaxis = np.arange(500,7000,200),
              xlabel = 'Qtot',
              ylabel = 'Entries')

# %% [markdown]
# #### Water comparisons

# %%
readFile('snoplus_simple_h2o','pbomb.root')

# %%
readFile('snoplusnative_h2o','pbomb.root')

# %%
plotComparison(datasets = ['snoplus_simple_h2o', 'snoplusnative_h2o'],
              datakey = 'nhit',
              figname = 'PBomb_nhit_native_vs_simple_water',
              xaxis = np.arange(0,200,2),
              xlabel = 'Nhits',
              ylabel = 'Entries')
# Out:
# **** neck *****
#
# snoplus_simple_h2o
# SUM  3.0
# Mean  0.003
# Std   0.0546900356555
#
# snoplusnative_h2o
# SUM  8.0
# Mean  0.008
# Std   0.0890842298053
#
# **** top *****
#
# snoplus_simple_h2o
# SUM  119738.0
# Mean  119.738
# Std   10.7303008346
#
# snoplusnative_h2o
# SUM  116543.0
# Mean  116.543
# Std   10.9010160536
#
# **** middle *****
#
# snoplus_simple_h2o
# SUM  41500.0
# Mean  41.5
# Std   6.34255469034
#
# snoplusnative_h2o
# SUM  39754.0
# Mean  39.754
# Std   6.21365303183
#
# **** bottom *****
#
# snoplus_simple_h2o
# SUM  122746.0
# Mean  122.746
# Std   11.0354648294
#
# snoplusnative_h2o
# SUM  120955.0
# Mean  120.955
# Std   10.8116129694

# %%
plotComparison(datasets = ['snoplus_simple_h2o', 'snoplusnative_h2o'],
              datakey = 'qtot',
              figname = 'PBomb_qtot_native_vs_simple_water',
              xaxis = np.arange(0,6000,200),
              xlabel = 'Qtot',
              ylabel = 'Entries')
# Out:
# **** neck *****
#
# snoplus_simple_h2o
# SUM  43.662755847
# Mean  0.043662755847
# Std   1.12605583388
#
# snoplusnative_h2o
# SUM  260.572568417
# Mean  0.260572568417
# Std   3.31058030849
#
# **** top *****
#
# snoplus_simple_h2o
# SUM  3798168.64599
# Mean  3798.16864599
# Std   510.931140531
#
# snoplusnative_h2o
# SUM  3690608.91395
# Mean  3690.60891395
# Std   501.866740987
#
# **** middle *****
#
# snoplus_simple_h2o
# SUM  1314740.28559
# Mean  1314.74028559
# Std   298.555953734
#
# snoplusnative_h2o
# SUM  1264306.61134
# Mean  1264.30661134
# Std   291.45630762
#
# **** bottom *****
#
# snoplus_simple_h2o
# SUM  3872057.24491
# Mean  3872.05724491
# Std   523.969734947
#
# snoplusnative_h2o
# SUM  3776815.05953
# Mean  3776.81505953
# Std   514.165129795
