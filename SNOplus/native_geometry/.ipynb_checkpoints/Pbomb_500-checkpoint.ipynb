# %% [markdown]
# ## Testing Aksel's "native" geometry<br> Photon bomb at 500 nm<br> Using labppo and water

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
sys.path.append('/home/jp/projects/snoplus/snoing/install/rat-dev/example/pyroot')
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import lowlevel_stats
reload(lowlevel_stats)
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available
# <module 'lowlevel_stats' from '/home/jp/projects/snoplus/python_modules/lowlevel_stats.pyc'>

# %%
outdir = '/home/jp/Dropbox/workflowy/snoplus/nativegeo_validation'

# %%
# Reading fcn
def readFile(one_dirname, fname):
    if one_dirname in data.keys():
        print 'This directory is already inside:', one_dirname
        print '... redoing only missing info'
    else:
        data[one_dirname] = {}
        
    file_name = os.path.join(basedir, one_dirname, fname)

    if not data[one_dirname].has_key('nhits'):
        data[one_dirname]['nhits'] = lowlevel_stats.getMChits(file_name)
    if not data[one_dirname].has_key('hit_t'):
        data[one_dirname]['hit_t'] = lowlevel_stats.getHitTimes_MC(file_name)
    if not data[one_dirname].has_key('pe_t'):
        data[one_dirname]['pe_t']  = lowlevel_stats.getPETimes_MC(file_name)
    
    # Getting the charges
    if not data[one_dirname].has_key('qtot'):
        snoqtot_aux, snoqpmt_aux, snoxpmt_aux= \
            lowlevel_stats.getPEcharge_light(file_name)
    
        data[one_dirname]['qtot'] = snoqtot_aux
        data[one_dirname]['qpmt'] = snoqpmt_aux
        data[one_dirname]['pexpmt'] = snoxpmt_aux

    return

# %%
# Initialize the data dictionary
data = {}

# %%
basedir = '/home/jp/projects/snoplus/rundir/nativegeo_verification/pbomb'

# %%
mycolors = ['b','r','g','m','c', 'y', '0.6']
def plotComparison(datasets = [], datakey = '', scale_factor = [], 
                   labels = [], figname = '', xaxis = np.arange(0, 100, 2),
                   xlabel = 'Nhits', ylabel = 'Entries'):

    if len(scale_factor) == 0:
        scale_factor = [1.]*len(datasets)
    if len(labels) == 0:
        labels = datasets
    # Reading each of the files one by one
    nbins = []
    myfig = plt.figure(figsize=(8,5))

    for i, one_set in enumerate(datasets):
        n, x = np.histogram(data[one_set][datakey], xaxis)
        nbins.append(n)
        print '\n',labels[i]

        print 'SUM ', data[one_set][datakey].sum()*scale_factor[i]
        print 'Mean ', data[one_set][datakey].mean()*scale_factor[i]
        print 'Std  ', data[one_set][datakey].std()*scale_factor[i]
        
        jplot.unfilledBar(xaxis, nbins[-1]*scale_factor[i], 
                              color = mycolors[i])
        jplot.errorMark(xaxis, nbins[-1]*scale_factor[i], 
                        error=np.sqrt(nbins[-1])*scale_factor[i], color=mycolors[i],
                        label =labels[i] + ' ' + \
                            '\nmean=' + "%.2f" % data[one_set][datakey].mean() +\
                            '\nstd=' + "%.2f" % data[one_set][datakey].std()) 
    

    
        
        
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    #plt.ylim([0,])
    plt.legend(loc=0,ncol=1)
    if len(figname) > 0:
        myfig.savefig(os.path.join(outdir, figname + '.png'), dpi=300)

# %% [markdown]
# ### Using photon bomb

# %% [markdown]
# #### Scintillator comparisons

# %%
readFile('snoplusnative','pbomb.root')

# %%
readFile('snoplusnative_noropes','pbomb.root')

# %%
readFile('snoplus_simple','pbomb.root')

# %%
readFile('snoplus','pbomb.root')
# Out:
# This directory is already inside: snoplus
# ... redoing only missing info

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplusnative', 
                           'snoplus', 'snoplusnative_noropes'],
               datakey = 'nhits',
               scale_factor = [1.,1.,10., 10.],
               figname = 'PBomb_nhit_native_vs_simple',
               xaxis = np.arange(250,450,4),
               xlabel = 'Nhits',
               ylabel = 'Entries')
# Out:
# snoplus_simple
# SUM  3500026.0
# Mean  350.0026
# Std   17.691551465
#
# snoplusnative
# SUM  3397335.0
# Mean  339.7335
# Std   17.5789270933
#
# snoplus
# SUM  3370170.0
# Mean  3370.17
# Std   174.114534431
#
# snoplusnative_noropes
# SUM  3446560.0
# Mean  3446.56
# Std   185.000990268

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplusnative', 
                           'snoplus', 'snoplusnative_noropes'],
              datakey = 'qtot',
               scale_factor = [1.,1.,10., 10.],
              figname = 'PBomb_qtot_native_vs_simple',
              xaxis = np.arange(7000,15000,200),
              xlabel = 'Qtot',
              ylabel = 'Entries')
# Out:
# snoplus_simple
# SUM  110920413.639
# Mean  11092.0413639
# Std   858.683347052
#
# snoplusnative
# SUM  107623758.129
# Mean  10762.3758129
# Std   847.638683552
#
# snoplus
# SUM  106358824.629
# Mean  106358.824629
# Std   8122.70600425
#
# snoplusnative_noropes
# SUM  108831406.417
# Mean  108831.406417
# Std   8557.06126116

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplusnative', 
                           'snoplus', 'snoplusnative_noropes'],
              datakey = 'qpmt',
               scale_factor = [1.,1.,10., 10.],
              figname = 'PBomb_qpmt_native_vs_simple',
              xaxis = np.arange(0,90,2),
              xlabel = 'Q_per_pmt',
              ylabel = 'Entries')
# Out:
# snoplus_simple
# SUM  110920413.639
# Mean  31.0730074673
# Std   33.9893097387
#
# snoplusnative
# SUM  107623758.129
# Mean  31.0724524493
# Std   33.9956131369
#
# snoplus
# SUM  106358824.629
# Mean  309.626367522
# Std   336.915596413
#
# snoplusnative_noropes
# SUM  108831406.417
# Mean  309.730960221
# Std   337.796945133

# %%
plotComparison(datasets = ['snoplus_simple', 'snoplusnative', 
                           'snoplus', 'snoplusnative_noropes'],
              datakey = 'pexpmt',
               scale_factor = [1.,1.,10., 10.],
              figname = 'PBomb_pexpmt_native_vs_simple',
              xaxis = np.arange(0,6,1),
              xlabel = 'Q_per_pmt',
              ylabel = 'Entries')
plt.yscale('log')
# Out:
# snoplus_simple
# SUM  3569671.0
# Mean  1.01989842361
# Std   0.141472515161
#
# snoplusnative
# SUM  3463639.0
# Mean  1.01951647394
# Std   0.140111612054
#
# snoplus
# SUM  3435070.0
# Mean  10.1925718881
# Std   1.39229453277
#
# snoplusnative_noropes
# SUM  3513740.0
# Mean  10.1949189917
# Std   1.40039327913

# %% [markdown]
# #### Water comparisons

# %%
readFile('snoplus_simple_h2o','pbomb.root')

# %%
readFile('snoplusnative_h2o','pbomb.root')

# %%
plotComparison(datasets = ['snoplus_simple_h2o', 'snoplusnative_h2o'],
              datakey = 'nhits',
              figname = 'PBomb_nhit_native_vs_simple_water',
              xaxis = np.arange(200,350,4),
              xlabel = 'Nhits',
              ylabel = 'Entries')
# Out:
# snoplus_simple_h2o
# SUM  283987.0
# Mean  283.987
# Std   16.662677786
#
# snoplusnative_h2o
# SUM  277260.0
# Mean  277.26
# Std   16.3687629343

# %%
plotComparison(datasets = ['snoplus_simple_h2o', 'snoplusnative_h2o'],
              datakey = 'qtot',
              figname = 'PBomb_qtot_native_vs_simple_water',
              xaxis = np.arange(6000,12000,200),
              xlabel = 'Qtot',
              ylabel = 'Entries')
# Out:
# snoplus_simple_h2o
# SUM  8985009.83925
# Mean  8985.00983925
# Std   787.441443476
#
# snoplusnative_h2o
# SUM  8731991.15739
# Mean  8731.99115739
# Std   767.9153569

# %%
plotComparison(datasets = ['snoplus_simple_h2o', 'snoplusnative_h2o'],
              datakey = 'qpmt',
              figname = 'PBomb_qpmt_native_vs_simple_water',
              xaxis = np.arange(0,90,2),
              xlabel = 'Q_per_pmt',
              ylabel = 'Entries')
# Out:
# snoplus_simple_h2o
# SUM  8985009.83925
# Mean  31.130501411
# Std   34.1660532633
#
# snoplusnative_h2o
# SUM  8731991.15739
# Mean  31.0023260907
# Std   33.9090326895
