# %% [markdown]
# ## Testing Aksel's "native" geometry<br> Photon bomb at 380nm & 500 nm<br> Using labppo only<br>Moved from photons from a single point to photons from a ball of 5cm radius

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
sys.path.append('/home/jp/projects/snoplus/snoing/install/rat-dev/example/pyroot')
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import lowlevel_stats
reload(lowlevel_stats)
import snoplots
reload(snoplots)
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available
# TClass::TClass:0: RuntimeWarning: no dictionary for class RAT::DU::ShadowingCalculator is available
# <module 'snoplots' from '/home/jp/projects/snoplus/python_modules/snoplots.pyc'>

# %%
outdir = '/home/jp/Dropbox/workflowy/snoplus/nativegeo_validation/photon_ball_1016'

# %%
# Initialize the data dictionary
data = {}

# %%
basedir = '/home/jp/projects/snoplus/ratout/nativegeo_validation/pbomb_ball'

# %% [markdown]
# ### Using photon bomb ball (the hits are distributed over a sphere)

# %% [markdown]
# #### Scintillator comparisons

# %%
lowlevel_stats.readFile(data, basedir, 'nativeb_shell','pbomb380.root', 'nativegeo')

# %%
lowlevel_stats.readFile(data, basedir, 'snoplusb_shell_nopipes','pbomb380.root', 'snoplusgeo')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplusgeo',
                                   'nativegeo'],
               datakey = 'nhit',
               figname = 'PBall380_nhit',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# /home/jp/projects/python_tools/jp_mpl.py:60: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if error == None:
# nativegeo top -0.0424290639088
# nativegeo middle 0.00357950263753
# nativegeo bottom -0.0338197969543
# nativegeo all -0.0319207789334

# %%
lowlevel_stats.readFile(data, basedir, 'nativeb','pbomb500.root', 'nativegeo_500')

# %%
lowlevel_stats.readFile(data, basedir, 'snoplusb_nopipes','pbomb500.root', 'snoplusgeo_500')

# %%
snoplots.plotComparison(data = data,
                        datasets = [
                           'nativegeo_500'],
               datakey = 'nhit',
               figname = 'PBall500_nhit',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)

# %%
# The test labeled as '2' is without any ropes
lowlevel_stats.readFile(data, basedir, 'snoplus_noropemod','pbomb380.root', 'snoplus_modnorope_380')
lowlevel_stats.readFile(data, basedir, 'snoplus_noropemod','pbomb500.root', 'snoplus_modnorope_500')
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod','pbomb380.root', 'nativegeo_modnorope_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod','pbomb500.root', 'nativegeo_modnorope_500')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_380',
                                    'nativegeo_modnorope_380'],
               datakey = 'nhit',
               figname = 'New_PBomb380_nhit_noropemod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_modnorope_380 top -0.00826905704954
# nativegeo_modnorope_380 middle -0.000940907329853
# nativegeo_modnorope_380 bottom -0.0101504813534
# nativegeo_modnorope_380 all -0.00801364115296

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_380',
                                    'snoplus_mod_380',
                                    ],
               datakey = 'nhit',
               figname = 'New_PBomb380_nhit_snoplusRope',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# snoplus_mod_380 top 0.0406819919015
# snoplus_mod_380 middle 0.0222865893032
# snoplus_mod_380 bottom 0.014487335265
# snoplus_mod_380 all 0.0267380539372

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_500',
                           'nativegeo_modnorope_500'],
               datakey = 'nhit',
               figname = 'New_PBomb500_nhit_noropemod',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_modnorope_500 top 0.00460215983889
# nativegeo_modnorope_500 middle 0.0274420060243
# nativegeo_modnorope_500 bottom 0.0060820714859
# nativegeo_modnorope_500 all 0.00857744711622

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_500',
                                    'snoplus_mod_500',
                                    ],
               datakey = 'nhit',
               figname = 'New_PBomb500_nhit_snoplusRope',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# snoplus_mod_500 top 0.0396826469515
# snoplus_mod_500 middle 0.0282048272894
# snoplus_mod_500 bottom 0.0158717525254
# snoplus_mod_500 all 0.0277445115485

# %%
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropedown','pbomb380.root', 'nativegeo_nodown_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modnorope_380',
                                    'nativegeo_nodown_380',
                                    'nativegeo_mod_380',
                                    ],
               datakey = 'nhit',
               figname = 'New_PBomb380_nhit_nativegeoRope',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_nodown_380 top 0.00474907587244
# nativegeo_mod_380 top 0.0271724829271
# nativegeo_nodown_380 middle 0.00801784200243
# nativegeo_mod_380 middle 0.00899472849928
# nativegeo_nodown_380 bottom 0.00355305525741
# nativegeo_mod_380 bottom 0.00232552401397
# nativegeo_nodown_380 all 0.00470506253025
# nativegeo_mod_380 all 0.0138359159313

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modnorope_500',
                                    'nativegeo_mod_500',
                                    ],
               datakey = 'nhit',
               figname = 'New_PBomb500_nhit_nativegeoRope',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_mod_500 top 0.0285078041726
# nativegeo_mod_500 middle 0.00677754761378
# nativegeo_mod_500 bottom 0.00734047806532
# nativegeo_mod_500 all 0.0162481621357

# %%
lowlevel_stats.readFile(data, basedir, 'snoplus_noropeup','pbomb380.root', 'snoplus_modnoup_380')
lowlevel_stats.readFile(data, basedir, 'snoplus_noropedown','pbomb380.root', 'snoplus_modnodown_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_380',
                                    'snoplus_mod_380',
                                    'snoplus_modnoup_380',
                                    'snoplus_modnodown_380',
                                    ],
               datakey = 'nhit',
               figname = 'New_PBomb380_nhit_snoplusRope',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# snoplus_mod_380 top 0.0406819919015
# snoplus_modnoup_380 top 0.0416421879837
# snoplus_modnodown_380 top 0.0108527425601
# snoplus_mod_380 middle 0.0222865893032
# snoplus_modnoup_380 middle 0.0138737708245
# snoplus_modnodown_380 middle 0.0066048004723
# snoplus_mod_380 bottom 0.014487335265
# snoplus_modnoup_380 bottom 0.011483939309
# snoplus_modnodown_380 bottom -0.00194410692588
# snoplus_mod_380 all 0.0267380539372
# snoplus_modnoup_380 all 0.0246307531858
# snoplus_modnodown_380 all 0.00472936199191

# %%
print 'Add a test with very fat ropes only for the native geometry'
print 'Make up fat, then down fat'

# %%
print 'Shadowing fractions at 380nm'
print 1-150.57/157.91
print 1-158.29/159.70
print 1-155.63/159.70
# Out:
# Shadowing fractions at 380nm
# 0.0464821733899
# 0.00882905447714
# 0.0254852849092

# %%
lowlevel_stats.readFile(data, basedir, 'nativegeo_3a','pbomb380.root', 'nativegeo_fatdown_380')

# %%
lowlevel_stats.readFile(data, basedir, 'nativegeo_3b','pbomb380.root', 'nativegeo_fatup_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_fatdown_380',
                                    'nativegeo_fatup_380',
                                    'nativegeo_mod_380',
                                    'nativegeo_modnorope_380'],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativegeoRope2',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)

# %%
# The tests labeled _4 are NATIVE GEOMETRY with/without ropes.
# The difference is that this is the original code (not the modified one where I changed how to read the dimensions)
lowlevel_stats.readFile(data, basedir, 'nativegeo_4a','pbomb380.root', 'nativegeo_origRope_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_4b','pbomb380.root', 'nativegeo_origNoRope_380')

# %%
print 'These tests need to be redone'

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modnorope_380',
                                   'nativegeo_mod_380',
                                   'nativegeo_origNoRope_380',
                                   'nativegeo_origRope_380'],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativeOriginalRope',
               #scale_factor = [1., 1., 10., 10.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# This is the code for the entrance: 0317#

# %%
1-159.6/155.6
# Out:
# -0.02570694087403602

# %%
# The 5a, 5b sets are the NEW native geometry, being as similar as possible to the old one.
lowlevel_stats.readFile(data, basedir, 'nativegeo_5a','pbomb380.root', 'nativegeo_origModRope_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_5b','pbomb380.root', 'nativegeo_origModNoRope_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_origModNoRope_380',
                                   'nativegeo_origModRope_380',
                                   'nativegeo_origNoRope_380',
                                   'nativegeo_origRope_380'],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativeChangeTest',
               #scale_factor = [1., 1., 10., 10.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# This is the code for the entrance: 0317#

# %%
# It does look like I've introduced a change here ... but where!?
# I think I found it. It was my own problem with the declaration of the SNORope.cc class
# Changed innerAV -> outerAV in the inheritance
# Testing in 5c, 5d
lowlevel_stats.readFile(data, basedir, 'nativegeo_5c','pbomb380.root', 'nativegeo_origModRope2_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_5d','pbomb380.root', 'nativegeo_origModNoRope2_380')

# %%
data.pop('nativegeo_origModRope2_380')
# Out:
# {'nhit': array([[170,  58, 150, 378],
#         [166,  47, 143, 356],
#         [167,  47, 148, 362],
#         ...,
#         [185,  51, 157, 393],
#         [172,  55, 167, 394],
#         [171,  60, 167, 398]]),
#  'qtot': array([[  5260.98391019,   1591.40667564,   4937.40357473,  11789.79416057],
#         [  5508.40666986,   1236.46891966,   4137.55682218,  10882.4324117 ],
#         [  4485.98528649,   1156.15783286,   4859.53780559,  10501.68092495],
#         ...,
#         [  5658.66010995,   1871.5246098 ,   4998.04379499,  12528.22851475],
#         [  5632.72871677,   2163.13416895,   5570.12012326,  13365.98300898],
#         [  5785.45745991,   2328.69498062,   5386.24447072,  13500.39691125]])}

# %%
lowlevel_stats.readFile(data, basedir, 'nativegeo_5c','pbomb380.root', 'nativegeo_origModRope2_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_origModNoRope2_380',
                                   'nativegeo_origModRope2_380',
                                   'nativegeo_origNoRope_380',
                                   'nativegeo_origRope_380'],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativeChangeTest_afterFix',
               scale_factor = [1., 1., 1., 1.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# This is the code for the entrance: 0317#

# %%
# Doesn't look like the SNORope.cc fix is sufficient for this ... I thought it would be, but the change is small.
# Need to debug all the Rope code, file by file

# The 5e is reverting the changes for SNORopeLoop.cc
lowlevel_stats.readFile(data, basedir, 'nativegeo_5e','pbomb380.root', 'nativegeo_origModRope3Loop_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_origModRope2_380',
                                    'nativegeo_origModRope3Loop_380',
                                   'nativegeo_origRope_380'],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativeChangeTest_afterFixLoop',
               scale_factor = [1., 1., 1., 1.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# This is the code for the entrance: 0317#

# %%
# In my 5f test I have completely replaced my modifications and gone to the 
# SNORope.cc file (original), and the SNORopeNet.cc file (original)
# Fuck this, none of the modifications are being built now --- so no F tests are planned

# Reverting back to Aksels is impossible without breaking something. The dimensions have to match and they dont
# I'll try instad making the down ropes extremely thick to try to get an effect

# %%
# At the end, the F set only tests that my changes didn't create chaos
lowlevel_stats.readFile(data, basedir, 'nativegeo_5f','pbomb380.root', 'nativegeo_origModRope3Loop2_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_origModRope3Loop_380',
        'nativegeo_origModRope3Loop2_380'
                                   ],
               datakey = 'nhit',
               figname = 'PBbomb380_nhit_nativeChangeTest_afterFixLoop2',
               scale_factor = [1., 5.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# This is the code for the entrance: 0317#

# %%
data.pop('nativegeo_redoNative_380')
# Out:
# {'nhit': array([[156,  52, 175, 383],
#         [150,  42, 183, 375],
#         [160,  49, 163, 372],
#         [172,  50, 166, 388],
#         [142,  64, 166, 372],
#         [154,  56, 154, 364],
#         [145,  56, 176, 377],
#         [149,  53, 165, 367],
#         [145,  48, 174, 367],
#         [183,  60, 175, 418],
#         [166,  55, 158, 379],
#         [152,  53, 160, 365],
#         [157,  38, 157, 352],
#         [154,  49, 163, 366],
#         [162,  54, 151, 367],
#         [138,  42, 146, 326],
#         [147,  68, 161, 376],
#         [151,  50, 159, 360],
#         [152,  56, 175, 383],
#         [181,  49, 153, 383],
#         [175,  49, 178, 402],
#         [165,  37, 151, 353],
#         [171,  58, 181, 410],
#         [152,  53, 170, 375],
#         [163,  52, 146, 361],
#         [159,  57, 161, 377],
#         [163,  60, 174, 397],
#         [146,  55, 169, 370],
#         [157,  55, 141, 353],
#         [180,  51, 156, 387],
#         [137,  51, 174, 362],
# ...

# %%
# My reversal of changes looks ok ... now let's go with huge ropes
lowlevel_stats.readFile(data, basedir, 'nativegeo_5g','pbomb380.root', 'nativegeo_redoNative_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_origModRope3Loop_380',
                                    'nativegeo_redoNative_380'
                                   ],
               datakey = 'nhit',
               #figname = 'PBbomb380_nhit_nativeChangeTest_afterFixLoop2',
               scale_factor = [1., 1.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)

# %%
data.pop('original_full')
data.pop('original_norope')
# Out:
# {'nhit': array([[156,  55, 170, 381],
#         [153,  60, 157, 370],
#         [164,  59, 135, 358],
#         [167,  42, 153, 362],
#         [174,  60, 184, 418],
#         [142,  52, 156, 350],
#         [167,  56, 154, 377],
#         [158,  59, 163, 380],
#         [176,  63, 164, 403],
#         [162,  48, 163, 373],
#         [164,  56, 164, 384],
#         [162,  53, 174, 389],
#         [179,  64, 183, 426],
#         [152,  52, 190, 394],
#         [151,  50, 155, 356],
#         [158,  51, 185, 394],
#         [145,  56, 146, 347],
#         [165,  54, 171, 390],
#         [162,  49, 150, 361],
#         [149,  56, 150, 355],
#         [175,  54, 181, 410],
#         [159,  51, 153, 363],
#         [155,  47, 180, 382],
#         [145,  52, 163, 360],
#         [159,  56, 145, 360],
#         [160,  65, 162, 387],
#         [151,  50, 154, 355],
#         [172,  64, 150, 386],
#         [154,  63, 173, 390],
#         [141,  46, 169, 356],
#         [149,  56, 158, 363],
# ...

# %%
basedir = '/home/jp/projects/snoplus/rundir/nativegeo_verification2/natgeo_staged'

# %%
lowlevel_stats.readFile(data, basedir, 'original_full','pbomb380.root')

# %%
lowlevel_stats.readFile(data, basedir, 'original_norope','pbomb380.root')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['original_full',
                                    'original_norope'
                                   ],
               datakey = 'nhit',
               #figname = 'PBbomb380_nhit_nativeChangeTest_afterFixLoop2',
               scale_factor = [1., 1.],
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)

# %%
lowlevel_stats.readFile(data, basedir, 'snoplus_rdown5','pbomb380.root', 'snoplus_rdown5_380')
lowlevel_stats.readFile(data, basedir, 'snoplus_rdown30','pbomb380.root', 'snoplus_rdown30_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['snoplus_modnorope_380',
                                    'snoplus_rdown5_380',
                                    'snoplus_mod_380',
                                    'snoplus_rdown30_380'
                                    ],
               datakey = 'nhit',
               #figname = 'New_PBomb380_nhit_snoplusRope',
               xaxis = np.arange(20,200,3),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# snoplus_rdown5_380 top 0.0201957031225
# snoplus_mod_380 top 0.0406819919015
# snoplus_rdown30_380 top 0.0730128047201
# snoplus_rdown5_380 middle 0.0145748390311
# snoplus_mod_380 middle 0.0222865893032
# snoplus_rdown30_380 middle 0.0439828053798
# snoplus_rdown5_380 bottom 0.00388198273982
# snoplus_mod_380 bottom 0.014487335265
# snoplus_rdown30_380 bottom 0.0304327507244
# snoplus_rdown5_380 all 0.0123596138224
# snoplus_mod_380 all 0.0267380539372
# snoplus_rdown30_380 all 0.0504733383558
