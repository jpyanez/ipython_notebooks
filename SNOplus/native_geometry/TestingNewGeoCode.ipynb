# %% [markdown]
# ### Testing my changes to the native geometry code

# %%
import ROOT, rat
import os, sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
sys.path.append('/home/jp/projects/snoplus/snoing/install/rat-dev/example/pyroot')
sys.path.append('/home/jp/projects/python_tools')
sys.path.append('/home/jp/projects/snoplus/python_modules')
import jp_mpl as jplot
import lowlevel_stats
reload(lowlevel_stats)
import snoplots
reload(snoplots)
# Out:
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available
# TClass::TClass:0: RuntimeWarning: no dictionary for class RAT::DU::ShadowingCalculator is available
# <module 'snoplots' from '/home/jp/projects/snoplus/python_modules/snoplots.pyc'>

# %%
# Initialize the data dictionary
data = {}

# %%
basedir = '/home/jp/projects/snoplus/rundir/nativegeo_verification2/pbomb_comparison'
outdir = ''

# %%
# Running without NCD anchors
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod','pbomb380.root', 'nativegeo_mod_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod','pbomb500.root', 'nativegeo_mod_500')

# %%
# With my code now, also running without NCD anchors
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod_newcode','pbomb380.root', 'nativegeo_modcode_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod_newcode','pbomb500.root', 'nativegeo_modcode_500')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_mod_380',
                                   'nativegeo_modcode_380'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# /home/jp/projects/python_tools/jp_mpl.py:60: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if error == None:
# nativegeo_modcode_380 top -0.0150122687138
# nativegeo_modcode_380 middle 0.000948554848789
# nativegeo_modcode_380 bottom 0.00133550146225
# nativegeo_modcode_380 all -0.00556670334649

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_mod_500',
                                   'nativegeo_modcode_500'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_modcode_500 top -0.0167721917062
# nativegeo_modcode_500 middle -0.00129591382173
# nativegeo_modcode_500 bottom 0.00215792516504
# nativegeo_modcode_500 all -0.00628014793368

# %%
# Running without NCD anchors and no rope
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod','pbomb380.root', 'nativegeo_modnorope_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod','pbomb500.root', 'nativegeo_modnorope_500')

# %%
# With my code now, also running without NCD anchors
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod_newcode','pbomb380.root', 'nativegeo_norope_modcode_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_noropemod_newcode','pbomb500.root', 'nativegeo_norope_modcode_500')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modnorope_380',
                                   'nativegeo_norope_modcode_380'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_norope_modcode_380 top -0.00138462502349
# nativegeo_norope_modcode_380 middle 0.00628525085708
# nativegeo_norope_modcode_380 bottom -0.00365175123678
# nativegeo_norope_modcode_380 all -0.00125539260276

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modnorope_500',
                                   'nativegeo_norope_modcode_500'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_norope_modcode_500 top 0.00281072420278
# nativegeo_norope_modcode_500 middle 0.00890935784245
# nativegeo_norope_modcode_500 bottom -0.00205533385829
# nativegeo_norope_modcode_500 all 0.00158272551676

# %%
# This is the modified AV neck thing
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod_newcode_AVneck','pbomb380.root', 'nativegeo_neckmod_380')
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod_newcode_longRope','pbomb380.root', 'nativegeo_ropemod_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_modcode_380',
                                   'nativegeo_neckmod_380',
                                   'nativegeo_ropemod_380'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
# Out:
# nativegeo_neckmod_380 top -0.00140859369052
# nativegeo_ropemod_380 top -0.00128803837466
# nativegeo_neckmod_380 middle 0.0115423997021
# nativegeo_ropemod_380 middle -0.00361165410034
# nativegeo_neckmod_380 bottom 0.000191925508138
# nativegeo_ropemod_380 bottom 0.00334940967428
# nativegeo_neckmod_380 all 0.00115062761506
# nativegeo_ropemod_380 all 0.000386224654007

# %%
lowlevel_stats.readFile(data, basedir, 'nativegeo_fullmod_newcode_20thick','pbomb380.root', 'nativegeo_thickrope_380')

# %%
snoplots.plotComparison(data = data,
                        datasets = ['nativegeo_norope_modcode_380',
                                    'nativegeo_modcode_380',
                                    'nativegeo_thickrope_380'],
               datakey = 'nhit',
               #figname = 'New_PBbomb380_nhit_fullmod',
               xaxis = np.arange(20,200,4),
               xlabel = 'Nhits',
               ylabel = 'Entries',
               outdir = outdir)
print 'I would expect the second one to be 30% more shadowed, so 1.6% or so'
# Out:
# nativegeo_modcode_380 top 0.0139334672248
# nativegeo_thickrope_380 top 0.0125507567368
# nativegeo_modcode_380 middle 0.00367258360692
# nativegeo_thickrope_380 middle 0.0139483983455
# nativegeo_modcode_380 bottom 0.00728307499416
# nativegeo_thickrope_380 bottom 0.0113640554128
# nativegeo_modcode_380 all 0.00958958693054
# nativegeo_thickrope_380 all 0.0122380130163
# I would expect the second one to be 30% more shadowed, so 1.6% or so
