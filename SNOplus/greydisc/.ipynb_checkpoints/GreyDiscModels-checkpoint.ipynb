# %%
import os, sys
sys.path.append('/home/jp/projects/python_tools')
import matplotlib.pyplot as plt
import numpy as np
import jp_mpl as jplot
# %matplotlib inline  
import pickle

# %% [markdown]
# ### Exploring the current model

# %%
sys.path.append('/home/jp/projects/snoplus/python_modules')
import ratdb_reader
reload(ratdb_reader)
# Out:
# <module 'ratdb_reader' from '/home/jp/projects/snoplus/python_modules/ratdb_reader.pyc'>

# %%
gd_0 = '/home/jp/projects/snoplus_testbed/snoing/install/rat-dev/data/GREY_DISC_PARAMETERS.ratdb'

# %%
gd_salt = '/home/jp/projects/snoplus_testbed/snoing/install/rat-dev/data/GREY_DISC_PARAMETERS_2.ratdb'

# %%
greydisc1 = ratdb_reader.readfile(gd_0)
greydisc2 = ratdb_reader.readfile(gd_salt)
# Out:
# String  type
# Number  version
# String  index
# Array  run_range
# Number  pass
# String  comment
# String  timestamp
# Number  travel_time
# Number  decay_constant
# Number  bounce_spread
# Number  disc_radius
# Number  collection_efficiency
# Array  absorption_probability
# Array  reflection_probability
# String  type
# Number  version
# String  index
# Array  run_range
# Number  pass
# String  comment
# String  timestamp
# Number  travel_time
# Number  decay_constant
# Number  bounce_spread
# Number  disc_radius
# Number  collection_efficiency
# Array  absorption_probability
# Array  reflection_probability

# %%
# Below follows Two huge (50*90=4500) blocks of absorption 
# probability and reflection probability taken from SNOMAN
# Functions evaluated as iTheta + iWavelength*90
# itheta given in radians (theta/degree) + 0.5
# iwlen = wlength*mm/(10.0) + 0.5
# Starts at 220 nm up until 710 nm
# Theta can take a value up to 90 (degrees)

# %%
abs1 = greydisc1['absorption_probability'].reshape([50,90])
ref1 = greydisc1['reflection_probability'].reshape([50,90])
abs2 = greydisc2['absorption_probability'].reshape([50,90])
ref2 = greydisc2['reflection_probability'].reshape([50,90])

# %%
xaxis = range(0,90)
yaxis = range(220, 720, 10)

myfig1 = plt.figure(figsize = (12,5))
myfig1.add_subplot(121)
plt.pcolor(xaxis, yaxis, abs1,
          vmin=0, vmax=0.14)
plt.colorbar()
plt.xlabel('Incidence angle')
plt.ylabel('Wavelength')

myfig1.add_subplot(122)
plt.pcolor(xaxis, yaxis, abs2,
          vmin=0, vmax=0.14)
plt.colorbar()
plt.xlabel('Incidence angle')
plt.ylabel('Wavelength')

plt.figure()
plt.pcolor(xaxis, yaxis, (abs2-abs1)/abs1)
plt.colorbar()

myfig2 = plt.figure(figsize = (12,5))

myfig2.add_subplot(121)
plt.pcolor(xaxis, yaxis, ref1,
          vmin=0, vmax=0.9)
plt.colorbar()
plt.xlabel('Incidence angle')
plt.ylabel('Wavelength')

myfig2.add_subplot(122)
plt.pcolor(xaxis, yaxis, ref2,
          vmin=0, vmax=0.9)
plt.colorbar()
plt.xlabel('Incidence angle')
plt.ylabel('Wavelength')
# Out:
# /home/jp/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: RuntimeWarning: divide by zero encountered in divide
# /home/jp/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: RuntimeWarning: invalid value encountered in divide

# %%
myfig3 = plt.figure(figsize=(12,5))
myfig3.add_subplot(121)
plt.pcolor(xaxis, yaxis, 1-(ref1 + abs1),
                          vmin=0, vmax=0.9)
plt.colorbar()
myfig3.add_subplot(122)
plt.pcolor(xaxis, yaxis, 1-(ref2 + abs2),
          vmin=0, vmax=0.9)
plt.colorbar()

# %%
# How much can I increase the collection efficiency before the sum of reflection+absorption is > 1?
room = (1-ref1[abs1>0]+abs1[abs1>0])/abs1[abs1>0]
print room.min()
room = (1-ref2[abs2>0]+abs2[abs2>0])/abs2[abs2>0]
print room.min()

print 'About a factor 6 - looks safe'
# Out:
# 6.59671216349
# 6.16956985425
# About a factor 6 - looks safe

# %% [markdown]
# ### Creating a new reflection model (keeping reflectivity and absorption)

# %%
# Tested specular reflection - looks ok, dip in the 35 degree direction

# %%
# PMT details
pmt_surfacer = 99.1 #mm
gdisc_radius = 137.7 #mm
# Presuming that the diagram in Moffat's thesis is correct
conversion = 315.2/458 # px to mm -- 458 px = 315.2 mm
pmt_radius = 327/2.*conversion
print pmt_radius
conc_radius = 455/2.*conversion
pmtdepth = 82*conversion
print pmtdepth
# Out:
# 112.522270742
# 56.4331877729

# %%
# The concentrator is more of an ellipse
b = 383 #px minor axis
a = 437 #px major axis
# The center is at the center of the disc#
# The PMT starts 82 pixels into the disc position

# %%
print b*conversion/2.
print 474*conversion/2.
print 'Depth of the intersection', 158*conversion
# Out:
# 131.792139738
# 163.105676856
# Depth of the intersection 108.737117904

# %%
# From r = [0, pmt_surfacer]
# For r > disc_radius
### Ellipse equation
# x**2/a**2 + y**2/b**2 = 1
def ellipse_y(x, majaxis = a*conversion/2.-12, minaxis = gdisc_radius):
    return -np.sqrt(minaxis**2*(1. - x**2/majaxis**2))
def circle(x, r = pmt_radius):
    return +np.sqrt(r**2 - x**2)

# %%
plt.figure(figsize=(10,4))
x2 = np.linspace(-pmt_radius, pmt_radius, 1000)
plt.plot(x2, circle(x2)-pmtdepth-pmt_radius)

x = np.linspace(-gdisc_radius, gdisc_radius, 1000)
plt.plot(x,ellipse_y(x)+20)
plt.vlines(gdisc_radius, -100, 0)
plt.ylim([-110, 0])
#plt.axis('equal')
# Out:
# (-110, 0)

# %%
pmt_surfacer = 82
def opticalSurface(x):
    # Treat x as an array
    xpmt  = np.abs(x)<pmt_surfacer
    y = np.zeros_like(x)
    
    #print xpmt
    
    # The PMT
    y[xpmt] = np.sqrt(pmt_radius**2-x[xpmt]**2)-pmtdepth-pmt_radius
    
    # The concentrator
    y[~xpmt] = 20.-np.sqrt(gdisc_radius**2*(1.-x[~xpmt]**2/(a*conversion/2.-12.)**2))
    
    return y

# %%
# Given that I have everything, can I trace a photon in and out of this region?
# Let's try!!

# %%
def opticalNormal(x, step = 0.001):
    x1 = x
    y1 = opticalSurface(np.array([x1]))

    x2 = x+step
    y2 = opticalSurface(np.array([x2]))
    
    pvec = np.array([(y1-y2)[0], step])
    
    return pvec/np.sqrt(np.sum(pvec**2))

def trackPoints(inpos, indir,
                maxy = 0, miny = -100, 
                stepsize = 0.01):
    # Check in how many steps I'll be surely out
    
    # If you start above zero, calculate to the bottom
    if inpos[1] > maxy:
        #print 'Calculating bottom'
        n = (miny - inpos[1])/(indir[1]*stepsize)
    # If you're inside the volume, calculate bottom and top
    else:
        # If are traveling down, calculate the bottom
        if indir[1] < 0:
            #print 'Calculating bottom'
            n =  (miny - inpos[1])/(indir[1]*stepsize)
        # If you are traveling up, calculate top
        else:
            #print 'Calculating top'
            n = (maxy - inpos[1])/(indir[1]*stepsize)

    if n > 100000:
        return [], []
    #else:
        #print 'Nsteps', n
    
    x = inpos[0] + indir[0]*stepsize*np.arange(10,n, 1)
    y = inpos[1] + indir[1]*stepsize*np.arange(10,n, 1)
    
    return x, y

def trackPhotonStep(inpos, indir):#, outpos, outdir):
    tolerance = 0.05
    indir /= np.sqrt(np.sum(indir**2))
    x,y = trackPoints(inpos, indir)
    if len(x) == 0:
        #print 'Photon is outside'
        return []
    contact = False
    for i, one_x in enumerate(x):
        # The top is at zero
        if np.abs(y[i]) < tolerance:
            #print 'Photon is leaving'
            break
        
        # The problem is here ... not moving and passes the condition
        ysurf = opticalSurface(np.array([one_x]))
        if np.abs(ysurf-y[i]) < tolerance:
            contact = True
            break
    #print 'This is the x,y of contact',one_x, y[i]
    if contact:
        normal = opticalNormal(one_x)
        outpos = np.array([one_x, y[i]])

        # Getting the reflection angle
        costheta = np.dot(normal, indir)
        theta  = np.arccos(-1.*costheta)
        
        outdir = np.array([normal[0]*np.cos(theta) - normal[1]*np.sin(theta),
                           normal[0]*np.sin(theta) + normal[1]*np.cos(theta)])
        outdir /= np.sqrt(np.sum(outdir**2))

        
        if np.abs(costheta) - np.abs(np.dot(outdir, normal)) > 1E-4:
            print 'Wrong'
        
        return [outpos, outdir]
    else:
        print 'Photon is outside'
        return []

# %%
def trackPhoton(inpos, indir):
    indir /= np.sqrt(np.sum(indir**2))
    positions =  []
    directions = []
    
    positions.append(inpos)
    directions.append(indir)
    out = trackPhotonStep(inpos, indir)
    while len(out) > 0:
        positions.append(out[0])
        directions.append(out[1])
        #print 'pos\n', positions
        #print 'dir\n', directions
        out = trackPhotonStep(out[0], out[1])
        #raw_input()
    
    print 'Steps ', len(positions)
    return positions, directions

# %%
trackPhotonStep(np.array([ 126.27457787,  -36.27457787]),
                np.array([-0.99815119,  0.06077989]))
# Out:
# [array([-132.23659972,  -20.5331941 ]), array([ 0.78908051,  0.6142898 ])]

# %%
p, d = trackPhoton(np.array([90, -5]),
                   np.array([10., -10]))
# Out:
# Photon is outside
# Steps  3

# %%
plt.figure(figsize=(10,4))
colors = ['r','g','b','c','m']
x = np.linspace(-gdisc_radius, gdisc_radius, 100000)


for iStep in range(len(d)-1):
    # The normal
    plt.quiver(p[iStep+1][0], 
               opticalSurface(np.array([p[iStep+1][0]])),
              *opticalNormal(p[iStep+1][0]), scale=10,color='k')
    
    # The incoming
    plt.quiver(p[iStep+1][0], p[iStep+1][1], d[iStep][0], d[iStep][1],
              color = colors[iStep], scale = 1, pivot='tip')    

# Last outgoing
plt.quiver(p[-1][0], p[-1][1], d[-1][0], d[-1][1],
            color = colors[iStep+1], scale = 2) 



y = opticalSurface(x)
plt.plot(x, y)

# %%
# Now lets try for multiple combinations

# %%
# - Retrieved the
    ## Impact point
    ## Convolute the impact point with a different function ... to be defined
    ## Do some raytracing myself here? Think about this
    ## I'm gonna need to add a factor for the incident angle phi
    ## Can I get the radius out?

# %%
plt.quiver?
