# %%
# %pylab inline
import ROOT, rat
import os, sys, pickle
import jp_mpl as jplot
from copy import deepcopy
# Out:
# Populating the interactive namespace from numpy and matplotlib
# TClass::TClass:0: RuntimeWarning: no dictionary for class omtext is available

# %% [markdown]
# ### Read all the PMT information from all the available files

# %%
# List the files
indir = '/home/jp/projects/snoplus/laserball_calibration/all_runs'
file_list = os.listdir(indir)
outdir = '/home/jp/projects/snoplus/laserball_calibration/all_runs_pckl'

# %%
quality_dir = '/home/jp/projects/snoplus/laserball_calibration/pmt_quality_occupancy'

# %% [markdown]
# ### Starting the shadowing calculator

# %%
du = rat.utility()
du.LoadDBAndBeginRun()
def wavelengthToEnergy(wavelength): # wl in nm
    hc = 1.2398 #eV * um
    return 1E-3*hc/wavelength # in MeV
light_path = du.GetLightPathCalculator()
shadow_path = du.GetShadowingCalculator()
laserE = wavelengthToEnergy(420.) # This won't matter for direct paths

def isPMTshadowed(source_position,
                 pmt_position,
                 tolerance = 0.):
    shadow_path.SetAllGeometryTolerances(tolerance)
    light_path.CalcByPosition(ROOT.TVector3(source_position),
                              ROOT.TVector3(pmt_position),
                              laserE, 0.)
    return shadow_path.CheckForShadowing(light_path)

# %% [markdown]
# ### Load the PMT information

# %%
pmt_info = pickle.load(open('/home/jp/projects/snoplus/python_modules/pmt_positions.pckl'))

# %% [markdown]
# #### Defining good and HQE PMTs to be "good"

# %%
good_pmts = (pmt_info['type'] == 1)

# %% [markdown]
# ## From here on, it's run dependent

# %% [markdown]
# ### Making manageable files from ROOT files

# %%
for file_index, file_name in enumerate(file_list):

    print 'Doing file', file_name ,
    outfile_path = os.path.join(outdir, file_name.rstrip('.root')+'.pckl')
    if os.path.isfile(outfile_path):
        print ' ... exists. Skipping it.'
        continue
    
    qhs       = np.zeros(pmt_radius.size)
    qhl       = np.zeros_like(qhs)
    occupancy = np.zeros_like(qhl)
    not_valid = 0
    reader = rat.socreader(os.path.join(indir, file_name))

    for soc, run in reader:
        # Get the run information
        result  = soc.GetFitResult(soc.GetFitNames()[0])
        vertex  = np.array(result.GetVertex(0).GetPosition())
        calib   = np.array(soc.GetCalib().GetPos())
        npulses = soc.GetNPulsesTriggered()

        # Go over the PMTs of interest
        # Should add some quality criteria here for PMTs
        for one_id in range(pmt_radius.size):
            try:
                pmt = soc.GetSOCPMT(one_id)
            except:
                not_valid +=1
                continue
            qhs[one_id] = np.sum(np.array(pmt.GetQHSs()))
            qhl[one_id] = np.sum(np.array(pmt.GetQHLs()))
            occupancy[one_id] = pmt.GetPromptOccupancy()
            
      
    reader.close()
    print '... done! - not valid PMTs ', not_valid
    
    # Save the file
    ofile = open(outfile_path, 'w')
    pickle.dump({'vertex':vertex, 'calib':calib, 'npulses':npulses,
                 'qhs':qhs, 'qhl':qhl, 'occupancy':occupancy}, ofile)
    ofile.close()
# Out:
# Doing file SOC_0000017377_reprocessed.root  ... exists. Skipping it.
# Doing file SOC_0000017375_reprocessed.root  ... exists. Skipping it.
# Doing file SOC_0000017378_reprocessed.root  ... exists. Skipping it.
# Doing file SOC_0000100558.root  ... exists. Skipping it.
# Doing file SOC_0000100559.root  ... exists. Skipping it.
# Doing file SOC_0000100560.root  ... exists. Skipping it.
# Doing file SOC_0000100554.root  ... exists. Skipping it.
# Doing file SOC_0000017386_reprocessed.root  ... exists. Skipping it.
# Doing file SOC_0000100556.root  ... exists. Skipping it.
# Doing file SOC_0000017376_reprocessed.root  ... exists. Skipping it.
# Doing file SOC_0000100555.root  ... exists. Skipping it.
# Doing file SOC_0000017384_reprocessed.root  ... exists. Skipping it.

# %% [markdown]
# ### Load the python-friendly files

# %%
# Load all the already available files
pfile_list = os.listdir(outdir)
data = []
for one_file in pfile_list:
    print 'Loading ', one_file
    infile = open(os.path.join(outdir, one_file))
    data.append(pickle.load(infile))
    data[-1]['run'] = int(one_file[4:14])
    infile.close()
# Out:
# Loading  SOC_0000100559.pckl
# Loading  SOC_0000100560.pckl
# Loading  SOC_0000100558.pckl
# Loading  SOC_0000017386_reprocessed.pckl
# Loading  SOC_0000017375_reprocessed.pckl
# Loading  SOC_0000017376_reprocessed.pckl
# Loading  SOC_0000017377_reprocessed.pckl
# Loading  SOC_0000100554.pckl
# Loading  SOC_0000100555.pckl
# Loading  SOC_0000100556.pckl
# Loading  SOC_0000017384_reprocessed.pckl
# Loading  SOC_0000017378_reprocessed.pckl

# %% [markdown]
# ## Run analysis starts here

# %%
quality_pmts = []

# %% [markdown]
# ### Select run index

# %%
iRun = 3
print 'Run', data[iRun]['run']
print 'Manip position', data[iRun]['calib']
# Out:
# Run 17386
# Manip position [    0.  -254.  4025.]

# %% [markdown]
# ### Find the shadowed PMTs

# %%
# PMTs that are shadowed
shadowed_pmts = np.zeros_like(pmt_info['type'], dtype=bool)
for i in range(1, shadowed_pmts.size):
    shadowed_pmts[i] = isPMTshadowed(data[iRun]['vertex'],
                                    pmt_info['xyz'][i],
                                    20.)
print np.sum(shadowed_pmts)
# Out:
# 2031

# %%
# Plotting the badq pmts
plt.figure(figsize=(16,10))

plt.scatter((pmt_info['phi']/np.pi)[shadowed_pmts], 
            pmt_info['costheta'][shadowed_pmts], 
            c='c',
            marker='o',lw = 0)
plt.xlabel('Phi / pi')
plt.ylabel('cos(theta)')

# %% [markdown]
# ### Define the quality cuts for PMTs - occupancy

# %% [markdown]
# #### Checking the occupancy

# %%
pmtbool = data[iRun]['occupancy'] > 0.
_ = plt.hist(data[iRun]['occupancy'][good_pmts*pmtbool*~shadowed_pmts])
print 'RMS', data[iRun]['occupancy'][good_pmts*pmtbool*~shadowed_pmts].mean()
print 'RMS', data[iRun]['occupancy'][good_pmts*pmtbool*~shadowed_pmts].std()
plt.xlabel('Occupancy')
plt.ylabel('Number of PMTs')
plt.title(data[iRun]['run'])
# Out:
# RMS 288.290930334
# RMS 155.055393442

# %%
zero_pmts = ((data[iRun]['occupancy'] == 0)*
             good_pmts*~shadowed_pmts)
neg_pmts = ((data[iRun]['occupancy'] < 0)*
             good_pmts*~shadowed_pmts)
# Plotting the zero pmts
plt.figure(figsize=(16,10))

plt.scatter((pmt_info['phi']/np.pi)[zero_pmts], 
            pmt_info['costheta'][zero_pmts], 
            c='r',
            marker='o',lw = 0)
plt.scatter((pmt_info['phi']/np.pi)[neg_pmts], 
            pmt_info['costheta'][neg_pmts], 
            c='g',
            marker='o',lw = 0)
plt.xlabel('Phi / pi')
plt.ylabel('cos(theta)')
print 'Sum', np.sum(zero_pmts), np.sum(neg_pmts)
# Out:
# Sum 250 286

# %% [markdown]
# ### Typical RMS for neighbors

# %%
nonzero_pmts = data[iRun]['occupancy'] > 0.


dist_tol = 800#in mm
pmts_in_range = np.zeros(9728)
for pmt_id in range(1, 9728):
    if not good_pmts[pmt_id] or shadowed_pmts[pmt_id] or ~nonzero_pmts[pmt_id]:
        continue
    pmt_dist = np.sqrt(np.sum((pmt_info['xyz'][pmt_id] - pmt_info['xyz'])**2, axis=1))
    
    dist_bool = pmt_dist[nonzero_pmts*good_pmts*~shadowed_pmts]<dist_tol
    
    pmts_in_range[pmt_id] =  np.sum(dist_bool)

# %% [markdown]
# #### Finding how close are the neighbors

# %%
_ = plt.hist(pmts_in_range[pmts_in_range>0])
plt.xlabel('Neighbors in range')
plt.ylabel('Number of PMTs')

# %% [markdown]
# For 80cm distance, you have at least 10 neighbors for each PMT. That should be enough to establish some sort of mean.

# %% [markdown]
# ### Figuring out a suitable RMS for cutting

# %%
n =plt.hist(data[iRun]['occupancy'][good_pmts*nonzero_pmts*~shadowed_pmts],
        np.linspace(0, data[iRun]['occupancy'][good_pmts*nonzero_pmts*~shadowed_pmts].max(), 101))
plt.xlabel('Occupancy')
plt.ylabel('Number of PMTs')

# %%
plt.plot((n[1][1:] + n[1][:-1])/2.,np.cumsum(n[0])/np.sum(n[0]))
plt.xlabel('Occupancy')
plt.ylabel('Cumulative')

# %%
padding = 2.5 # in percent
global_limits = np.percentile(data[iRun]['occupancy'][good_pmts*nonzero_pmts*~shadowed_pmts],
              [padding, 100-padding])
print global_limits
# Out:
# [  75.  574.]

# %%
n =plt.hist(data[iRun]['occupancy'][good_pmts*nonzero_pmts*~shadowed_pmts],
        np.linspace(0, data[iRun]['occupancy'][good_pmts*nonzero_pmts*~shadowed_pmts].max(), 101))
plt.xlabel('Occupancy')
plt.ylabel('Number of PMTs')
plt.axvline(x=global_limits[0], ymin = 0, ymax = n[0].max(), linestyle='--', color='r')
plt.axvline(x=global_limits[1], ymin = 0, ymax = n[0].max(), linestyle='--', color='r')

# %%
# Run this only once
goodq_pmts = np.ones_like(good_pmts)
pmt_quality = np.zeros(goodq_pmts.size, dtype=int)

# %%
goodq_pmts[(data[iRun]['occupancy']<global_limits[0])*
           good_pmts*nonzero_pmts*~shadowed_pmts] = False
goodq_pmts[(data[iRun]['occupancy']>global_limits[1])*
           good_pmts*nonzero_pmts*~shadowed_pmts] = False
print 'Plots removed by global cut', np.sum(goodq_pmts==False)
pmt_quality[~goodq_pmts] = 2
# Out:
# Plots removed by global cut 339

# %%
pmt_rms = np.zeros(9728)

for pmt_id in range(1, 9728):
    
    # Skip analysis for strange PMTs
    if not (good_pmts[pmt_id] and nonzero_pmts[pmt_id] and goodq_pmts[pmt_id] and ~shadowed_pmts[pmt_id]):
        continue
    
    # Find PMTs that are nearby
    pmt_dist = np.sqrt(np.sum((pmt_info['xyz'][pmt_id] - pmt_info['xyz'])**2, axis=1))
    dist_bool = pmt_dist<dist_tol
    
    good_neighbors = dist_bool*good_pmts*nonzero_pmts*goodq_pmts*~shadowed_pmts
    
    # Get the occupancy of nearby PMTs that are good and nearby
    occupancy = data[iRun]['occupancy'][good_neighbors]
    pmt_rms[pmt_id] = occupancy.std()

# %%
n = plt.hist(pmt_rms[good_pmts*nonzero_pmts*goodq_pmts*~shadowed_pmts], np.linspace(0., np.max(pmt_rms), 101))
plt.xlabel('RMS (mm)')
plt.ylabel('PMT combinations')
use_rms = pmt_rms[good_pmts*nonzero_pmts*goodq_pmts*~shadowed_pmts].mean()
print 'Use RMS', use_rms
# Out:
# Use RMS 60.7841354156

# %%
plt.plot((n[1][1:] + n[1][:-1])/2.,np.cumsum(n[0])/np.sum(n[0]))
plt.xlabel('RMS (mm)')
plt.ylabel('Cumulative')

# %%
nonzero_pmts = data[iRun]['occupancy'] > 0.
pmt_rms = np.zeros(9728)
#rms_scaling = 1.5
absolute_rms = 1.5*use_rms
last_removed = 0
while True:
    for pmt_id in range(1, 9728):

        # Skip analysis for strange PMTs
        if not (good_pmts[pmt_id] and nonzero_pmts[pmt_id] and goodq_pmts[pmt_id] and ~shadowed_pmts[pmt_id]):
            continue

        # Find PMTs that are nearby
        pmt_dist = np.sqrt(np.sum((pmt_info['xyz'][pmt_id] - pmt_info['xyz'])**2, axis=1))
        dist_bool = pmt_dist<dist_tol

        good_neighbors = dist_bool*good_pmts*nonzero_pmts*goodq_pmts*(~shadowed_pmts)

        # Get the occupancy of nearby PMTs that are good and nearby
        occupancy = data[iRun]['occupancy'][good_neighbors]
        pmt_rms[pmt_id] = occupancy.std()

        # Define the PMTs that are in mean+/- 2*RMS
        #limits = [occupancy.mean() - rms_scaling*occupancy.mean(), #absolute_rms, 
        #          occupancy.mean() + rms_scaling*occupancy.mean()]#absolute_rms]

        # Define the PMTs that are in mean+/- 2*RMS
        limits = [occupancy.mean() - absolute_rms, 
                  occupancy.mean() + absolute_rms]

        # Get the PMTs that are outside the boundaries
        outside_pmts = (data[iRun]['occupancy']<limits[0])+(data[iRun]['occupancy']>limits[1])

        # Mark as "bad" those pmts that were previously good, but are outside boundaries
        goodq_pmts[good_neighbors*outside_pmts] = False

        if pmt_id % 2000 == 0:
            print pmt_id

        if np.isnan(pmt_rms[pmt_id]):
            print pmt_id, occupancy
        if False: #np.sum(good_neighbors*outside_pmts) > 0: #np.sum(outside_pmts*dist_bool*nonzero_pmts*good_pmts) > 0:
            print occupancy.mean()
            output = plt.hist(occupancy, np.linspace(0, 6000, 101))
            print occupancy
            plt.title('PMT '+ "%i" % pmt_id + ' - RMS: '+ "%.2f" % occupancy.std())
            plt.xlabel('Occupancy')
            plt.ylabel('Number of PMTs')
            plt.axvline(x=limits[0], ymin = 0, ymax = output[0].max(), linestyle='--', color='r')
            plt.axvline(x=limits[1], ymin = 0, ymax = output[0].max(), linestyle='--', color='r')

            plt.show()
            raw_input()

    pmt_quality[~goodq_pmts*(pmt_quality!=2)] = 3
    neighbor_removed =  np.sum(pmt_quality == 3)
    if neighbor_removed == last_removed:
        break
    else:
        print neighbor_removed, last_removed
        last_removed = deepcopy(neighbor_removed)
# Out:
# 2000
# 4000
# 6000
# 8000
# 1085 0
# 2000
# 4000
# 6000
# 8000

# %%
# PMTs that ended up marked as bad in my study
pmt_quality[~goodq_pmts*(pmt_quality!=2)] = 3

# PMTs that have zero or negative occupancy
pmt_quality[~nonzero_pmts] = 1

# Put the PMTs that are anyway not used to zero
pmt_quality[~good_pmts] = 4

print 'PMTs removed by my method', np.sum(pmt_quality == 3)
print 'Shadowed pmts', np.sum(shadowed_pmts)
# Out:
# PMTs removed by my method 1085
# Shadowed pmts 2031

# %%
# Plotting the badq pmts
plt.figure(figsize=(13,8))

plt.scatter((pmt_info['phi']/np.pi)[shadowed_pmts], 
            pmt_info['costheta'][shadowed_pmts], 
            c='c',
            marker='o',lw = 0)

zero_pmts = ((data[iRun]['occupancy'] == 0)*
             good_pmts*~shadowed_pmts)
neg_pmts = ((data[iRun]['occupancy'] < 0)*
             good_pmts*~shadowed_pmts)

# Plotting the zero pmts
plt.scatter((pmt_info['phi']/np.pi)[zero_pmts], 
            pmt_info['costheta'][zero_pmts], 
            c='r',
            marker='o',lw = 0)
plt.scatter((pmt_info['phi']/np.pi)[neg_pmts], 
            pmt_info['costheta'][neg_pmts], 
            c='g',
            marker='o',lw = 0)

# In blue are the global outliers, in black local outliers
plt.scatter((pmt_info['phi']/np.pi)[pmt_quality==2], 
            pmt_info['costheta'][pmt_quality==2], 
            c='b',
            marker='o',lw = 0)
plt.scatter((pmt_info['phi']/np.pi)[pmt_quality==3], 
            pmt_info['costheta'][pmt_quality==3], 
            c='k',
            marker='o',lw = 0)


plt.title('Run '+str(data[iRun]['run']))

plt.xlabel('Phi / pi')
plt.ylabel('cos(theta)')
print 'Sum', np.sum(zero_pmts), np.sum(neg_pmts)
# Out:
# Sum 250 286

# %%
print 'PMTs left', np.sum(pmt_quality==0)
# Out:
# PMTs left 7277

# %%
data[iRun]['run']
# Out:
# 17386

# %%
pickle.dump(pmt_quality, 
            open(os.path.join(quality_dir, "%i" % data[iRun]['run'] + '_PMT_quality.pckl'), 'w'))

# %%
quality_pmts.append(pmt_quality==0)

# %%
for i in range(len(quality_pmts)):
    print np.sum(quality_pmts[i])
# Out:
# 6389
# 6493
# 6526
# 6784
# 6672
# 6694
# 6418
# 6499
# 6580
# 6820
# 6665

# %%
nbins = 21
cos_bins = np.linspace(-1, 1, nbins+1)
cos_centers = (cos_bins[1:] + cos_bins[:-1])/2.
fig = plt.figure(figsize=(12,4))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
aux=0
for iRun, one_run in enumerate(data):
    if iRun ==  3:
        aux =-1
        continue
        
    valid_pmts = quality_pmts[iRun+aux]
    pos_key = 'vertex'


    one_run = data[iRun]
    one_run['distance'] = np.sqrt(np.sum((pmt_info['xyz'] - one_run[pos_key])**2,axis=1))
    one_run['costheta'] = (pmt_info['xyz'][:,2] - one_run[pos_key][2])/one_run['distance']
    one_run['phi'] = np.arctan2((pmt_info['xyz'][:,1] - one_run[pos_key][1]), 
                                (pmt_info['xyz'][:,0] - one_run[pos_key][0]))

    qhs = np.zeros(nbins)
    qhl = np.zeros_like(qhs)
    occ = np.zeros_like(qhs)

    for ibin in range(nbins):
        ipmts = (one_run['costheta']>cos_bins[ibin])*(one_run['costheta']<cos_bins[ibin+1])
        pmt_distance = one_run['distance'][valid_pmts*ipmts]


        qhs[ibin] = one_run['qhs'][valid_pmts*ipmts].mean()
        qhl[ibin] = one_run['qhl'][valid_pmts*ipmts].mean()
        occ[ibin] = one_run['occupancy'][valid_pmts*ipmts].mean() 

        qhs[ibin] = np.median(one_run['qhs'][valid_pmts*ipmts])
        qhl[ibin] = np.median(one_run['qhl'][valid_pmts*ipmts])
        occ[ibin] = np.median(one_run['occupancy'][valid_pmts*ipmts])

        #print 'Range', cos_bins[ibin], cos_bins[ibin+1], \
        #    ', mu:', pmt_distance.mean(), \
        #    ', sigma:', pmt_distance.std()

    #print rqhs, rqhl, rocc
    ax1.plot(cos_centers, qhs/qhs.mean(), 'x', label = one_run['run'])
    ax2.plot(cos_centers, occ/occ.mean(), 'x', label = one_run['run'])
ax1.set_ylim(0.5, 1.5)
ax2.set_ylim(0.5, 1.5)
plt.legend(loc=0,ncol=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eca0c8c93945> in <module>()
#       1 nbins = 21
# ----> 2 cos_bins = np.linspace(-1, 1, nbins+1)
#       3 cos_centers = (cos_bins[1:] + cos_bins[:-1])/2.
#       4 fig = plt.figure(figsize=(12,4))
#       5 ax1 = fig.add_subplot(121)
#
# NameError: name 'np' is not defined
