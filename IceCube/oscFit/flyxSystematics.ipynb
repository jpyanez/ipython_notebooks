# %%
import os, sys
import matplotlib.pyplot as plt
# %matplotlib inline 
sys.path.append('/home/jp/projects/python_tools')
import jp_mpl as jplot
sys.path.append('/home/jp/projects/icecube/oscFit/modules')
import pickle, modNuFlux
import numpy as np
from copy import deepcopy
reload(modNuFlux)
# Out:
# <module 'modNuFlux' from '/home/jp/projects/icecube/oscFit/modules/modNuFlux.pyc'>

# %%
flux = modNuFlux.modNuFlux()

# %%
flux.makeFluxTables(nu_nubar = 1., uphor_ratio = 1)

# %%
plt.pcolor(10**flux.modflux_maps['ebins'], flux.modflux_maps['zbins'],
           flux.modflux_maps['uphor_ratio'][14])
plt.colorbar()

# %%
print flux.modflux_maps['uphor_ratio'][12].shape
print flux.modflux_maps['uphor_ratio'][14].shape
print flux.modflux_maps['nubar_ratio'][12].shape
print flux.modflux_maps['nubar_ratio'][14].shape
print flux.modflux_maps['nubar_ratio'][-12].shape
print flux.modflux_maps['nubar_ratio'][-14].shape
# Out:
# (160, 150)
# (160, 150)
# (160, 150)
# (160, 150)
# (160, 150)
# (160, 150)

# %%
plt.pcolor(10**flux.modflux_maps['ebins'], flux.modflux_maps['zbins'],
           flux.modflux_maps['nubar_ratio'][12])
plt.colorbar()

# %%
flux.modRatio
