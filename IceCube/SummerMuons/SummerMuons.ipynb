# %%
import os, sys
import matplotlib.pyplot as plt
# %matplotlib inline 
sys.path.append('/home/jp/projects/python_tools')
import jp_mpl as jplot
import pickle
import numpy as np

# %%
data = pickle.load(open('/home/jp/projects/icecube/holeice_summer/charge_data.pckl'))

# %%
data.keys()
# Out:
# ['q', 'cosE']

# %%
plt.plot(data['cosE'], (data['q']), 'x')

# %%
cosz_axis = np.linspace(-1,1,21)
qaxis = np.array([-np.inf, 0.00001, np.inf])

b, x, y = np.histogram2d(data['q'], data['cosE'], [qaxis, cosz_axis])

# %%
wb, x, y = np.histogram2d(data['q'], data['cosE'], [qaxis, cosz_axis], weights = data['q'])

# %%
jplot.unfilledBar(qaxis, b[:,3])
plt.yscale('log')

# %%
ratio = b[1,:]/np.sum(b, axis=0)

# %%
print np.sqrt(b[1,:])/b[1,:]
# Out:
# [ 0.02801659  0.03061384  0.03074377  0.02708645  0.02486824  0.02464071
#   0.0236558   0.02408415  0.02320567  0.0229961   0.02270383  0.02321817
#   0.02378257  0.02353756  0.02314344  0.02279804  0.02279212  0.02382303
#   0.02407019  0.02444849]

# %%
wratio = wb[1,:]/np.sum(b, axis=0)

# %%
jplot.unfilledBar(cosz_axis, ratio)

# %%
jplot.unfilledBar(cosz_axis, wratio)
