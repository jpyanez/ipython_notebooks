# %% [markdown]
# Z factor computation with split energies
# -----------------------------------------------------

# %%
# %load_ext autoreload
# %autoreload 2
import CBcm

# %%
from copy import deepcopy
import pickle, os, sys

# %%
sys.path.append('/home/jp/projects/ipython_notebooks/MCEq/prd_paper_2021/plot_scripts_anatoli')
sys.path.append('/home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules')
import mufit_config, quickflux

# %%
import sys
sys.path.insert(0, '/home/jp/software/MCEq')

# %%
outdir = '/home/jp/projects/atm_nu/ddm_results/daemon_prd_submission'
if not os.path.isdir(outdir):
    os.mkdir(outdir)

# %%
import matplotlib.pyplot as plt
import numpy as np

#import solver related modules
from MCEq.core import MCEqRun
import mceq_config as config
#import primary model choices
import crflux.models as pm

import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 150
# Out:
# /home/jp/software/MCEq/mceq_config.py:309: FutureWarning: Config dictionary is deprecated. Use 'import mceq_config as config' instead of 'from mceq_config import config'; and 'config.variable instead of config['variable']
#   warnings.warn(warn_str, FutureWarning)

# %%
mceq_ddm = MCEqRun(
#provide the string of the interaction model
interaction_model='DPMJETIII191',
#primary cosmic ray flux model
primary_model = (pm.SimplePowerlaw27, None),
# Zenith angle in degrees. 0=vertical, 90=horizontal
theta_deg=0.0
)
# Out:
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$

# %%
### Getting the rest of the models for the Z-factor plot

base_model = 'DPMJETIII191'
# config.mceq_db_fname = 'mceq_db_lext_dpm191_v131.h5'
config.enable_default_tracking = False
config.adv_set['fix_dpmjet_neutral_kaons'] = True
mceq = MCEqRun(
    interaction_model=base_model,
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_sibyll = MCEqRun(
    interaction_model='SIBYLL23C',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_epos = MCEqRun(
    interaction_model='eposlhc',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_qgs = MCEqRun(
    interaction_model='qgsjetii04',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
# Out:
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): DPMJETIII191
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): SIBYLL23C
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): EPOSLHC
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): QGSJETII04
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$

# %%
from references import Honda2006ZFactors
honda_zfac = Honda2006ZFactors(floc='/home/jp/projects/atm_nu/plot_scripts_anatoli/Sanuki_Honda_2006_ZFactors.csv')

# %% [markdown]
# Define variables and angles
# -------------------------

# %%
#Power of energy to scale the flux (the results will be returned as E**mag * flux)
mag = 3

#obtain energy grid (fixed) of the solution for the x-axis of the plots
e_grid = mceq_ddm.e_grid

#Dictionary for results
flux = {}

#Define a zenith angle, counted positively from vertical direction. Theta = 0. means vertical, theta = 90. horizontal
theta = 60.

# %% [markdown]
# ## Creating or loading the original DDM Z-factors

# %%
from MCEq.ddm import DataDrivenModel
from os.path import join

# %%
ddm = DataDrivenModel(
    join(config.data_dir, 'CarbonTargetFits_inclna49K_pp2pC4.npy'))

# %%
#print(ddm)

# %% [markdown]
# Here needs to go the energy of what we have chosen for the extrapolation point

# %%
for prim, sec in ddm.channels:
    if prim != 2212:
        continue
    ddm.clone_datapoint(prim, sec, 158, 2e4)
    #ddm.clone_datapoint(prim, sec, 158, 2e5)
    ddm.clone_datapoint(prim, sec, 158, 2e6)
ddm.clone_datapoint(prim, 2212, 158., 31.0)
ddm.clone_datapoint(prim, -2212, 158., 31.0)
ddm.clone_datapoint(prim, 2112, 158., 31.0)

# %%
# Inject DDM in MCEq
mceq_ddm.inject_ddm(ddm)

# %%
secs = [211, -211, 321, -321, 2212, 2112, 310]
#zfac_fname = 'zfac_ddm_original_splitvhe_lepn.pkl'
zfac_fname_original = '/home/jp/projects/atm_nu/plot_scripts_anatoli/zfac_ddm_original_splitvhe.pkl' #This contains the LE stuff
zfac_fname = 'zfac_lib_smart.pkl' # The new one

# %%
# if os.path.isfile(zfac_fname):
#     zfac_lib = pickle.load(open(zfac_fname, 'rb'))
# if os.path.isfile(zfac_fname_original):
#     zfac_ddm_original = pickle.load(open(zfac_fname_original,'rb'))
    
# Do the common settings instead
common_settings = pickle.load(open('/home/jp/projects/atm_nu/ddm_results/final_settings/common_settings_daemon.pkl', 'rb'))
zfac_lib = common_settings['zfactors_labeled']

# %% [markdown]
# ## Getting the Z-factors from the fits

# %%
def plotZfac(zfac_ddm_cal_list, 
            plot_other_models = True,
            ylim_scale = 2,
            #err_scale = {'pi+':2, 'pi-':5, 'K+':7 , 'K-':10 , 'p':4, 'n':2}
            ):
    ddm_color = "violet"
    ddm_extension = "0.8" #"darkgreen"
    for m in [mceq_ddm]:
        m.set_primary_model(pm.SimplePowerlaw27())
    # plot_impy_direct = False
    # plot_other_models = True
    # plot_honda = True
    fs = 12
    secs = [211, -211, 321, -321, 2212, 2112, 310]
    secs_label = ['pi+','pi-','K+','K-','p','n','K0']
    elabels = ['31G','158G','20T','2P']
    pdg2name = {
        211: r"$\pi^+$",
        -211: r"$\pi^-$",
        321: r"K$^+$",
        -321: r"K$^-$",
        2212: r"p",
        -2212: r"$\bar{\rm p}$",
        2112: r"n",
        310: r"K$^0_S$",
        130: r"K$^0_L$",
    }
    particle_labels = {
        211: r"$\pi^+$",
        -211: r"$\pi^-$",
        321: r"K$^+$",
        -321: r"K$^-$",
        2212: r"p+$\bar{\rm p}$",
        2112: r"n+$\bar{\rm n}$",
        310: r"K$^0_S$+K$^0_L$",
    }
    colors = ["C1", "C2", "C3", "C4", "C6"]

    
    #print(zfac_ddm_cal_list)
    ref_errors = list(zfac_ddm_cal_list.keys())[0]
    print('Using reference errors from fit', ref_errors)

    def add_zfactor(mceq_obj, prim, sec1, sec2=None):
        if sec2 is not None:
            return mceq_obj.z_factor(prim, sec1, use_cs_scaling=False) + mceq_obj.z_factor(
                prim, sec2, use_cs_scaling=False
            )
        else:
            return mceq_obj.z_factor(prim, sec1, use_cs_scaling=False)




    fig, axes = plt.subplots(2, 4, sharex=True, figsize=(9, 4.7))
    ms = 4
    prim = 2212
    r = [321, -321, -2212]
    #secs = [211, -211, 321, -321, 2212, 2112, 310]
    for i, seci in enumerate(secs):
        ax = axes.flatten()[i]  # [i//3, i%3]

        norm = 1.0  # zair[2]

        if seci == 2212:
            sec2 = -2212
        elif seci == 2112:
            sec2 = -2212
        elif seci == 310:
            sec2 = 130
        else:
            sec2 = None

        # DDM model
        #ddm_zfac = add_zfactor(mceq_ddm, prim, seci, sec2)
        #print(ddm_zfac)
        ax.semilogx(
            mceq_ddm.e_grid,
            add_zfactor(mceq_ddm, prim, seci, sec2),
            c="violet",
            lw=3,
            alpha=0.8,
            label="DDM in MCEq, no tune" if i == 0 else "_nolabel_",
        )
        
        if plot_other_models:
            sel = np.where(mceq.e_grid > 80)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_sibyll, prim, seci, sec2)[sel]/norm,c=colors[0], ls='-', 
                        label='SIBYLL-2.3d' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 5.)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq, prim, seci, sec2)[sel]/norm,c=colors[1],
                        label='DPMJET-III 19.1' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 30.)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_epos, prim, seci, sec2)[sel]/norm,c=colors[2], 
                        label='EPOS-LHC' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 100)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_qgs, prim, seci, sec2)[sel]/norm,c=colors[3], 
                        label='QGSJET-II-04' if i == 0 else '_nolabel_')
        if seci != -2212 and prim == 2212:# and plot_honda:
            ax.semilogx(*honda_zfac.get_data(pdgid=seci),c=colors[4],ls='-',label='HKKMS' if i == 0 else '_nolabel_')
            
        ax.set_xticks([1.0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7])
        ax.set_ylim(-ax.get_ylim()[1] / 20, ylim_scale * ax.get_ylim()[1])
        ax.set_xlim(10, 3e7)
        if i < 4:
            ax.text(0.05, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        elif i < 6:
            ax.text(0.05, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        else:
            ax.text(0.05, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        ax.tick_params(bottom=True, top=True, left=True, right=True, direction="in")

        
        # The points from DDM
        r = pickle.load(open(calibration_results[ref_errors], 'rb'), encoding='latin1')
        for ien, ena in enumerate([31, 158, 2e4, 2e6]):
            this_label = secs_label[i]+'_'+elabels[ien]
#             if ena > 200:
#                 if ena < 1E6 and ('pi' not in secs_label[i]):
#                     continue
#                 this_label = 'vhe3_'+secs_label[i]
#             else:
#                 this_label = elabels[ien] + secs_label[i]
            if this_label in zfac_lib:
                (valj, errj) = zfac_lib[this_label]
                if ena > 200:
                    error_scaling = r['flux_parameters'][this_label][-1]
                    print('Error scale', this_label, error_scaling)
                    thiscolor= ddm_extension
                else:
                    error_scaling = 1
                    thiscolor = ddm_color
                
                # Scale the errj to my estimates
                ax.errorbar(
                    ena,
                    valj,
                    yerr=errj*error_scaling,
                    marker="o",
                    markersize=4,
                    color=thiscolor,
                    label="NA49 & NA61" if i == 3 and ien == 0 else "_nolabel_",
                )    
        
            
                
        for it, tune in enumerate(zfac_ddm_cal_list):
            # Open the file
            result = pickle.load(open(calibration_results[tune], 'rb'), encoding='latin1')['params']
            for ien, ena in enumerate([31, 158, 2e4, 2e6]):
                this_label = secs_label[i] +"_"+elabels[ien]

                if this_label in result:
                    valjcal = (zfac_lib[this_label][0]+
                               zfac_lib[this_label][1]*result[this_label]['value'])
                    errjcal = zfac_lib[this_label][1]*result[this_label]['error']

                    #print(this_label, valjcal, errjcal)
                    ax.errorbar(
                        ena*(1+it/4.),
                        valjcal,
                        yerr=errjcal,
                        marker="o",
                        markersize=4,
                        color="C"+"%i" % it,
                        label= tune if i == 3 and ien == 0 else "_nolabel_",
                        zorder=9
                    )

                    #print(i, ien, i == 3 and ien == 0)
                    

        if i // 4 == 1:
            ax.set_xlabel(r"$E_p$ [GeV]", fontsize=fs - 1)
        elif i == 3:
            ax.set_xlabel(r"$E_p$ [GeV]", fontsize=fs - 1)
        else:
            ax.xaxis.set_ticklabels([])

        if i % 4 == 0:
            ax.set_ylabel(r"$Z_{p,\mathrm{sec}}$", fontsize=fs)


    for ax in axes.flatten():
        ax.tick_params(axis="both", which="major", labelsize=fs - 3)

    axes[-1, -1].set_visible(False)
    axes[-1, 0].set_xticks([1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7])

    fig.legend(
        fontsize=fs - 2,
        frameon=False,
        ncol=1,
        bbox_to_anchor=(0.985, 0.48),
        bbox_transform=fig.transFigure,
        title="Proton-air",
    )

    fig.tight_layout(w_pad=-0.05, h_pad=-1)
    plt.subplots_adjust(wspace=0.3)
    # plt.subplots_adjust(top = 0.9)
    plt.savefig("DDM_tune_Zfactors_splitVHE.png", dpi=200)
    return fig
    # plt.savefig('../../figures/zfactors_protons.png', dpi=300)
    # plt.savefig('../../figures/zfactors_protons.pdf')
    # fig.savefig('/Users/mhuber/AtmosphericShowers/Paper_hadronic_Flux_uncertainties/Plots/Zfactors_2212_impy_sibyll_norm.pdf',
    #    bbox_inches="tight")

# %%
my_params = ['scale','GSF_1','GSF_2',
                   'GSF_3','GSF_4',
                   'GSF_5','GSF_6']

my_params = ['K+_158G', 'K+_2P', 'K+_31G', 'K-_158G', 'K-_2P', 'K-_31G', 'n_158G', 'n_2P', 
                   'p_158G', 'p_2P', 'pi+_158G', 'pi+_20T', 'pi+_2P', 'pi+_31G', 
                   'pi-_158G', 'pi-_20T', 'pi-_2P', 'pi-_31G']
# my_params = ['l3c_align',
#                    'l3c_bfield',
#                    'l3c_eloss',
#                    'l3c_overb',
#                    'l3c_normHor',
#                    'l3c_normVert',
#                    'l3c_pres',
#                    'mn_escale',
#                    'bess_align',
#                    'bess_finres']
nparams = len(my_params)
def resultSummary(calfiles):
    fig = plt.figure(figsize=(10,4))
    chi2_list = np.zeros(len(calfiles))
    cal_names = []
    for ires, fresult in enumerate(calfiles):
        if calfiles[fresult] == '':
            continue
        with open(calfiles[fresult], 'rb') as data_file:
            result = pickle.load(data_file, encoding='latin1')
        cal_names.append(fresult)
        chi2_list[ires] = result['chi2']
        test_params = {}
        values = np.zeros(nparams)
        errors = np.zeros_like(values)
        for iphys, one_phys in enumerate(my_params):
            if one_phys in result['params']:
                values[iphys] = result['params'][one_phys]['value']
                errors[iphys] = result['params'][one_phys]['error']
                
        plt.errorbar(np.arange(len(my_params))+0.1*ires,
                 values, errors, fmt='+', label=fresult)
    _ = plt.xticks(range(nparams), 
                       my_params, rotation='vertical')
    
    plt.legend(loc=0)
    plt.ylim(-4,4)
    
    
    fig = plt.figure(figsize=(10,4))
    plt.plot(np.arange(chi2_list.size),
            chi2_list, 'x')
    _ = plt.xticks(range(chi2_list.size), 
                    cal_names, rotation='vertical')     
    plt.ylabel('Chi2')
    
    return fig
    #plt.ylim(-1,1)

# %%
# Comparison between multiplicative and additive systematic approach
calibration_results = {
    #'ddmgsf':'/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v19_final.pkl',
    #'ddmgsf_bess':'/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v19hybrid.pkl',
    #'daemonflux4': '/home/jp/projects/atm_nu/ddm_results/prd22_daemon_v4.pkl',
    #'daemonflux': '/home/jp/projects/atm_nu/ddm_results/prd22_daemon_v5.pkl',
    'daemonflux': '/home/jp/projects/atm_nu/ddm_results/daemon_prd_submission.pkl',
    'minus_bess': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nobess.pkl',
    'minus_cms': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nocms.pkl',
    'minus_deis': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nodeis.pkl',
    'minus_l3c': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nol3c.pkl',
    'minus_minos': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nominos.pkl',
    'minus_mutron': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nomutron.pkl',
    'minus_opera': '/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_noopera.pkl',
}

# %%
#zfacs = makeZfac(calibration_results)
fig = plotZfac(calibration_results,
         plot_other_models = True,
        ylim_scale=2.)
            #err_scale = {'pi+':2.5, 'pi-':10, 'K+':10 , 'K-':20 , 'p':6, 'n':2.5})
#fig.savefig(os.path.join(outdir, 'zfactors_daemon.pdf'))
resultSummary(calibration_results)
# Out:
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# Using reference errors from fit daemonflux
# Error scale pi+_20T 1.8
# Error scale pi+_2P 1.8
# Error scale pi-_20T 10
# Error scale pi-_2P 10
# Error scale K+_2P 10
# Error scale K-_2P 20.0
# Error scale p_2P 6
# Error scale n_2P 2.5

# %%
calibration_results.get(0)

# %% [markdown]
# #### Still need to add a loop to include multiple models in the test

# %%
#calibration_results = {}
#calibration_results.update({'DDM+GSF':''})

# %%
# Global plot configuration

fs = 16
fs_ticks = 16
alpha_mod = .15
data_marker_config = {'lw':1, 'linestyle':'None', 'alpha':.8, 'markersize':3.}
#colors = ['black', 'blue', 'orange', 'green', 'red', 'grey', 'pink']
#norm = Normalize(0,10)
#s_m = cm.ScalarMappable(cmap=cm.magma, norm=norm)
#s_m.set_array([])
#colors = [s_m.to_rgba(i) for i in range(10)]

# %%
import quickflux2
qflux_ddmgsf = quickflux2.MCEq_fastflux(flux_tables='ddmgsf-v19')
qflux_daemon = quickflux2.MCEq_fastflux(flux_tables='daemon-v3')
# Out:
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221115_newstyle_smarter.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v19
# Adjusting DEIS name
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230207_nousertab.pkl
# Excluded params removed from known_params.
# No calibration file for daemon-v3
# Adjusting DEIS name

# %%
def comparePlots(calfiles,
                reference = 'ddmgsf',
                particle = 'numuflux'):
    #reference = 'CAL_2E'
    #particle = 'numuflux'
    exp = 'cms'
    angle = '0.0000'

    fluxes = []
    errors = []
    keys   = []

    mag=3
    egrid = np.logspace(-1,5.99)


    # Load all the fluxes
    refindex = None
    for ires, fresult in enumerate(calfiles):
        
        if 'daemon' in fresult:
            print('Using DAEMON quickflux')
            qflux = qflux_daemon
        else:
            qflux = qflux_ddmgsf
        
        keys.append(fresult)
        if reference == fresult:
            refindex = ires
            
        #print(keys[-1])

        if calfiles[fresult] == '':
            # Use default spline
            fluxes.append(qflux.get_flux_new(egrid, exp, angle, particle, use_calibration = False))
            errors.append(qflux.get_error_new(egrid, exp, angle, particle, use_calibration = False))

        else:
            print(fresult)
            with open(calfiles[fresult], 'rb') as data_file:
                result = pickle.load(data_file, encoding='latin1')

            # Splines path
            splines_path = result['flux_tables']
#             splines_path = os.path.join(mufit_config.jacobians_dir,
#                                         mufit_config.jacobians[result['flux_tables']])

            # Set up the quickflux calibration file and 
            #print(keys[ires], calfiles[fresult], splines_path)
            
            qflux.set_mufit_spl(splines_path)
            qflux.set_calibration_file(calfiles[fresult])
           # print(quickflux._calibration_file)
            #quickflux.load_splines()
            
            
            fluxes.append(deepcopy(qflux.get_flux_new(egrid, exp, angle, 
                                                 particle, 
                                                 use_calibration=True)))
            if 'daemonflux' in fresult:       
                errors.append(qflux.get_error_new(egrid, exp, angle, 
                                                      particle, 
                                                      use_calibration=True))
            else:
                print('Skipping errors for ')
                print(fresult)
                errors.append(np.ones_like(fluxes[-1])*1E-5)
            
            #print(quickflux.cal_values)
    ## Plotting all the fluxes here
    
    ## TOP plot, the fluxes
    fig, axes = plt.subplots(
        3, 1, figsize=(5.5, 8.5), sharex=True, gridspec_kw={"height_ratios": (1, 1,1)}
    )
    ax = axes[0]

    #ax.set_ylabel(r"($E$/GeV)$^3~\Phi_{\nu_\mu}$ (GeV cm$^{2}$ s sr)$^{-1}$", fontsize=fs - 4)
    ax.set_ylabel(particle)

    #print(keys)
    for ires in range(len(keys)):

        ax.fill_between(egrid, fluxes[ires] + errors[ires], fluxes[ires] - errors[ires], 
                        facecolor="C"+"%i" % ires, alpha=alpha_mod, label=keys[ires])
        ax.plot(egrid, fluxes[ires], ls="solid", color="C"+"%i" % ires, 
                alpha=0.8)

    ## Calibrated DDM+GSF
    #ax.fill_between(egrid, flux_cal + err_cal, flux_cal - err_cal, 
    #                facecolor="r", alpha=alpha_mod)
    #ax.plot(egrid, flux_cal, ls="-.", color="r", alpha=0.8)

    ax.set_xscale("log")

    if not 'ratio' in particle:
        ax.set_yscale("log")
        ax.set_ylim(2e-4, 1.5e-1)


    ax.set_xlim(0.1, 9e5)
    ax.tick_params(
        axis="both",
        which="both",
        right=True,
        top=True,
        direction="inout",
        labelsize=fs_ticks - 5,
    )
    
    
    
    # ## MIDDLE figure - ratios    
    ax = axes[1]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, fluxes[ires]/fluxes[refindex],
                   c="C"+"%i" % ires, ls='-')
        ax.fill_between(egrid,
                        (fluxes[ires]+errors[ires])/fluxes[refindex],
                        (fluxes[ires]-errors[ires])/fluxes[refindex],
                       facecolor = "C"+"%i" % ires,
                       alpha=alpha_mod, label=keys[ires])

    ax.set_ylabel("Model/"+keys[refindex])
    #ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)
    ax.set_ylim(0.8, 1.2)
    
    
    ax = axes[2]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, errors[ires]/fluxes[ires],
                   c="C"+"%i" % ires, ls='-', label=keys[ires])

    ax.set_ylabel("Model error")
    ax.set_xlabel(r"$E}$ (GeV)", fontsize=fs - 4)    
    plt.tight_layout(h_pad=-0.5)
    plt.legend(loc=0)

# %%
#calibration_results.update({'DDM+GSF':''})
myref = 'daemonflux'

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'muflux')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'muratio')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'numuflux')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'nueflux')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'numuratio')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'nueratio')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'flavorratio')
# Out:
# Using DAEMON quickflux
# daemonflux
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# minus_bess
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_bess
# minus_cms
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_cms
# minus_deis
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_deis
# minus_l3c
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_l3c
# minus_minos
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_minos
# minus_mutron
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_mutron
# minus_opera
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/daemonsplines_20230323_2.pkl
# Entering version with 5 entries
# Excluded params removed from known_params.
# No calibration file for daemon-v4
# Skipping errors for
# minus_opera

# %%
import pickle

# %%
mydata = pickle.load(open('/home/jp/projects/atm_nu/ddm_results/nminusone_daemonx/daemon_prd_submission_nodeis.pkl', 'rb'),
                    encoding='latin1')

# %%
mydata
# Out:
# {'corr_matrix': array([[ 1.        , -0.04298305, -0.01618898, ..., -0.01834479,
#           0.1222128 , -0.01708775],
#         [-0.04298305,  1.        , -0.11890476, ..., -0.06378011,
#           0.04593616,  0.01522773],
#         [-0.01618898, -0.11890476,  1.        , ...,  0.08073975,
#          -0.2219994 , -0.06996413],
#         ...,
#         [-0.01834479, -0.06378011,  0.08073975, ...,  1.        ,
#           0.07387785, -0.008909  ],
#         [ 0.1222128 ,  0.04593616, -0.2219994 , ...,  0.07387785,
#           1.        ,  0.00597585],
#         [-0.01708775,  0.01522773, -0.06996413, ..., -0.008909  ,
#           0.00597585,  1.        ]]),
#  'flux_parameters': {'K+_2P': [5.110296765773629, False, -19, 19, 0, 10],
#   'p_2P': [5.466037247706817, False, -16, 16, 0.0, 6],
#   'pi-_158G': [2.7443694470049103, False, -10, 10, 0.0, 1],
#   'pi+_2P': [-3.067796060202917, False, -5.5, 5.5, 0.0, 2.0],
#   'K-_2P': [-24.45007320520227, False, -25, 30, 5.0, 20.0],
#   'K-_31G': [-0.4102358461336857, False, -10, 10, 0.0, 1],
#   'n_158G': [1.0613194141485636, False, -10, 10, 0.0, 1],
#   'pi+_31G': [-4.052598502641182, False, -10, 10, 0.0, 1],
#   'K+_158G': [0.43580597142111266, False, -10, 10, 0.0, 1],
#   'K-_158G': [0.034534664006635296, False, -10, 10, 0.0, 1],
#   'pi-_20T': [4.604688395406946, False, -33, 33, 0, 10],
#   'pi+_158G': [-0.12321646476593351, False, -10, 10, 0.0, 1],
#   'p_158G': [-0.1114075541566848, False, -10, 10, 0.0, 1],
#   'GSF_4': [0.19219917360443084, False, -4, 4, 0.0, 1],
#   'GSF_5': [-1.904924164179922, False, -4, 4, 0.0, 1],
#   'GSF_6': [0.2645951200302994, False, -4, 4, 0.0, 1],
#   'GSF_1': [1.07674450787795, False, -4, 4, 0.0, 1],
#   'GSF_2': [0.12180167139978959, False, -4, 4, 0.0, 1],
#   'GSF_3': [0.04517016249088179, False, -4, 4, 0.0, 1],
#   'K+_31G': [-1.0624625249740234, False, -10, 10, 0.0, 1],
#   'pi+_20T': [0.06817043858900362, False, -5.5, 5.5, 0.0, 2.0],
#   'pi-_31G': [-2.357411903494584, False, -10, 10, 0.0, 1],
#   'pi-_2P': [8.378825812097581, False, -33, 33, 0, 10],
#   'n_2P': [2.1994280601256317, False, -6, 6, 0, 2.5]},
#  'chi2': 192.91467888631823,
#  'flux_tables': 'daemon-v4',
#  'cov_params': ['K+_2P',
#   'p_2P',
#   'pi-_158G',
#   'pi+_2P',
#   'K-_2P',
#   'K-_31G',
#   'n_158G',
#   'pi+_31G',
#   'K+_158G',
#   'K-_158G',
#   'pi-_20T',
#   'pi+_158G',
#   'p_158G',
#   'GSF_4',
#   'GSF_5',
#   'GSF_6',
#   'GSF_1',
#   'GSF_2',
#   'GSF_3',
#   'K+_31G',
#   'pi+_20T',
#   'pi-_31G',
#   'pi-_2P',
#   'n_2P',
#   'deis_norm',
#   'deis_mscat',
#   'l3c_bfield',
#   'l3c_overb',
#   'mn_escale',
#   'bess_align',
#   'l3c_normVert',
#   'deis_bfield',
#   'l3c_normHor',
#   'bess_finres',
#   'l3c_eloss',
#   'l3c_pres',
#   'l3c_align'],
#  'params': {'K+_2P': {'is_const': False,
#    'name': 'K+_2P',
#    'number': 0,
#    'value': 5.158209094506553,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 19.0,
#    'lower_limit': -19.0,
#    'has_upper_limit': True,
#    'error': 2.0471231743109755,
#    'is_fixed': False},
#   'p_2P': {'is_const': False,
#    'name': 'p_2P',
#    'number': 1,
#    'value': 5.252732397252295,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 16.0,
#    'lower_limit': -16.0,
#    'has_upper_limit': True,
#    'error': 5.0182842686048135,
#    'is_fixed': False},
#   'l3c_bfield': {'is_const': False,
#    'name': 'l3c_bfield',
#    'number': 26,
#    'value': 0.138971084471752,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.9056256782018175,
#    'is_fixed': False},
#   'l3c_overb': {'is_const': False,
#    'name': 'l3c_overb',
#    'number': 27,
#    'value': -1.6604546618124831,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.723436455342277,
#    'is_fixed': False},
#   'pi-_158G': {'is_const': False,
#    'name': 'pi-_158G',
#    'number': 2,
#    'value': 2.7422668754948774,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.635665109519528,
#    'is_fixed': False},
#   'pi+_2P': {'is_const': False,
#    'name': 'pi+_2P',
#    'number': 3,
#    'value': -3.06380388420785,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.5,
#    'lower_limit': -5.5,
#    'has_upper_limit': True,
#    'error': 1.6422129360209636,
#    'is_fixed': False},
#   'K-_2P': {'is_const': False,
#    'name': 'K-_2P',
#    'number': 4,
#    'value': -24.31498623786434,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 30.0,
#    'lower_limit': -25.0,
#    'has_upper_limit': True,
#    'error': 6.098658720135912,
#    'is_fixed': False},
#   'K-_31G': {'is_const': False,
#    'name': 'K-_31G',
#    'number': 5,
#    'value': -0.2150431648794715,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.9812288028620779,
#    'is_fixed': False},
#   'n_158G': {'is_const': False,
#    'name': 'n_158G',
#    'number': 6,
#    'value': 1.0611021709781134,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.7058463409987947,
#    'is_fixed': False},
#   'bess_align': {'is_const': False,
#    'name': 'bess_align',
#    'number': 29,
#    'value': -0.35811627445358685,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.727754804394535,
#    'is_fixed': False},
#   'pi+_31G': {'is_const': False,
#    'name': 'pi+_31G',
#    'number': 7,
#    'value': -1.5135068587338285,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.7572129773749845,
#    'is_fixed': False},
#   'K+_158G': {'is_const': False,
#    'name': 'K+_158G',
#    'number': 8,
#    'value': 0.4363484144527501,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.8486272680817564,
#    'is_fixed': False},
#   'K-_158G': {'is_const': False,
#    'name': 'K-_158G',
#    'number': 9,
#    'value': 0.03561894479567407,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.9570515407018583,
#    'is_fixed': False},
#   'mn_escale': {'is_const': False,
#    'name': 'mn_escale',
#    'number': 28,
#    'value': -1.6949795044436113,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.3033627225783153,
#    'is_fixed': False},
#   'deis_mscat': {'is_const': False,
#    'name': 'deis_mscat',
#    'number': 25,
#    'value': 0.0,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 3.0,
#    'lower_limit': -3.0,
#    'has_upper_limit': True,
#    'error': 0.5,
#    'is_fixed': True},
#   'l3c_pres': {'is_const': False,
#    'name': 'l3c_pres',
#    'number': 35,
#    'value': 2.987436791984579,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.39697139304209683,
#    'is_fixed': False},
#   'deis_bfield': {'is_const': False,
#    'name': 'deis_bfield',
#    'number': 31,
#    'value': 0.0,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 3.0,
#    'lower_limit': -3.0,
#    'has_upper_limit': True,
#    'error': 0.5,
#    'is_fixed': True},
#   'pi-_20T': {'is_const': False,
#    'name': 'pi-_20T',
#    'number': 10,
#    'value': 4.575482780872072,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 33.0,
#    'lower_limit': -33.0,
#    'has_upper_limit': True,
#    'error': 0.7102797218786492,
#    'is_fixed': False},
#   'deis_norm': {'is_const': False,
#    'name': 'deis_norm',
#    'number': 24,
#    'value': 0.0,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 3.0,
#    'lower_limit': -3.0,
#    'has_upper_limit': True,
#    'error': 0.5,
#    'is_fixed': True},
#   'pi+_158G': {'is_const': False,
#    'name': 'pi+_158G',
#    'number': 11,
#    'value': -0.1237230335568249,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.08478691919898296,
#    'is_fixed': False},
#   'p_158G': {'is_const': False,
#    'name': 'p_158G',
#    'number': 12,
#    'value': -0.11167912755992226,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.9154883223004919,
#    'is_fixed': False},
#   'GSF_4': {'is_const': False,
#    'name': 'GSF_4',
#    'number': 13,
#    'value': 0.19184831983620843,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.9782533658143082,
#    'is_fixed': False},
#   'GSF_5': {'is_const': False,
#    'name': 'GSF_5',
#    'number': 14,
#    'value': -0.7903247033036869,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.9324103731091449,
#    'is_fixed': False},
#   'GSF_6': {'is_const': False,
#    'name': 'GSF_6',
#    'number': 15,
#    'value': 0.26591439162690556,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.9589705901400032,
#    'is_fixed': False},
#   'GSF_1': {'is_const': False,
#    'name': 'GSF_1',
#    'number': 16,
#    'value': 1.0807029393133796,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.6007762783700801,
#    'is_fixed': False},
#   'GSF_2': {'is_const': False,
#    'name': 'GSF_2',
#    'number': 17,
#    'value': 0.12236134999998782,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.9425235765376276,
#    'is_fixed': False},
#   'GSF_3': {'is_const': False,
#    'name': 'GSF_3',
#    'number': 18,
#    'value': 0.04451949275442946,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 4.0,
#    'lower_limit': -4.0,
#    'has_upper_limit': True,
#    'error': 0.945318879466867,
#    'is_fixed': False},
#   'K+_31G': {'is_const': False,
#    'name': 'K+_31G',
#    'number': 19,
#    'value': -1.062246729829555,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.7385999281867441,
#    'is_fixed': False},
#   'pi+_20T': {'is_const': False,
#    'name': 'pi+_20T',
#    'number': 20,
#    'value': 0.0643057513452927,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.5,
#    'lower_limit': -5.5,
#    'has_upper_limit': True,
#    'error': 0.12880706208547998,
#    'is_fixed': False},
#   'pi-_31G': {'is_const': False,
#    'name': 'pi-_31G',
#    'number': 21,
#    'value': -2.357756263622716,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 10.0,
#    'lower_limit': -10.0,
#    'has_upper_limit': True,
#    'error': 0.3725265703976812,
#    'is_fixed': False},
#   'pi-_2P': {'is_const': False,
#    'name': 'pi-_2P',
#    'number': 22,
#    'value': 8.35966466390662,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 33.0,
#    'lower_limit': -33.0,
#    'has_upper_limit': True,
#    'error': 6.472895465678803,
#    'is_fixed': False},
#   'l3c_align': {'is_const': False,
#    'name': 'l3c_align',
#    'number': 36,
#    'value': 0.07077994144319621,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.10622503887030588,
#    'is_fixed': False},
#   'l3c_normHor': {'is_const': False,
#    'name': 'l3c_normHor',
#    'number': 32,
#    'value': -1.0182801729069824,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.46219399285586404,
#    'is_fixed': False},
#   'n_2P': {'is_const': False,
#    'name': 'n_2P',
#    'number': 23,
#    'value': 2.2105218344860447,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 6.0,
#    'lower_limit': -6.0,
#    'has_upper_limit': True,
#    'error': 1.8805193238226074,
#    'is_fixed': False},
#   'l3c_eloss': {'is_const': False,
#    'name': 'l3c_eloss',
#    'number': 34,
#    'value': 0.34849506916203143,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.8827170263151176,
#    'is_fixed': False},
#   'bess_finres': {'is_const': False,
#    'name': 'bess_finres',
#    'number': 33,
#    'value': 0.5199341013178485,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.8145452926980434,
#    'is_fixed': False},
#   'l3c_normVert': {'is_const': False,
#    'name': 'l3c_normVert',
#    'number': 30,
#    'value': -0.928472751174584,
#    'has_limits': True,
#    'has_lower_limit': True,
#    'upper_limit': 5.0,
#    'lower_limit': -5.0,
#    'has_upper_limit': True,
#    'error': 0.44403093370194435,
#    'is_fixed': False}},
#  'fmin': {'hesse_failed': False,
#   'has_reached_call_limit': False,
#   'has_accurate_covar': False,
#   'ncalls': 3568,
#   'has_posdef_covar': False,
#   'up': 1.0,
#   'edm': 8.175887612798112e-05,
#   'is_valid': True,
#   'is_above_max_edm': False,
#   'has_covariance': True,
#   'has_made_posdef_covar': True,
#   'has_valid_parameters': True,
#   'fval': 237.54294513307747,
#   'tolerance': 0.1,
#   'nfcn': 3568},
#  'cov_matrix': array([[ 4.21002376e+00, -4.51175323e-01, -2.11320365e-02, ...,
#          -3.34026468e-02,  9.97111182e-02, -3.72468290e-03],
#         [-4.51175323e-01,  2.61704810e+01, -3.86976566e-01, ...,
#          -2.89545535e-01,  9.34426472e-02,  8.27566968e-03],
#         [-2.11320365e-02, -3.86976566e-01,  4.04724168e-01, ...,
#           4.55819323e-02, -5.61585638e-02, -4.72843182e-03],
#         ...,
#         [-3.34026468e-02, -2.89545535e-01,  4.55819323e-02, ...,
#           7.87501776e-01,  2.60690161e-02, -8.39879456e-04],
#         [ 9.97111182e-02,  9.34426472e-02, -5.61585638e-02, ...,
#           2.60690161e-02,  1.58113603e-01,  2.52433358e-04],
#         [-3.72468290e-03,  8.27566968e-03, -4.72843182e-03, ...,
#          -8.39879456e-04,  2.52433358e-04,  1.12855903e-02]]),
#  'bins': 244}
