# %% [markdown]
# Z factor computation with split energies
# -----------------------------------------------------

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from copy import deepcopy
import pickle, os, sys

# %%
sys.path.append('/home/jp/projects/ipython_notebooks/MCEq/prd_paper_2021/plot_scripts_anatoli')
sys.path.append('/home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules')
import mufit_config, quickflux

# %%
import sys
sys.path.insert(0, '/home/jp/software/MCEq')

# %%
outdir = '/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v18'
if not os.path.isdir(outdir):
    os.mkdir(outdir)

# %%
import matplotlib.pyplot as plt
import numpy as np

#import solver related modules
from MCEq.core import MCEqRun
import mceq_config as config
#import primary model choices
import crflux.models as pm

import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 150
# Out:
# /home/jp/software/MCEq/mceq_config.py:309: FutureWarning: Config dictionary is deprecated. Use 'import mceq_config as config' instead of 'from mceq_config import config'; and 'config.variable instead of config['variable']
#   warnings.warn(warn_str, FutureWarning)

# %%
mceq_ddm = MCEqRun(
#provide the string of the interaction model
interaction_model='DPMJETIII191',
#primary cosmic ray flux model
primary_model = (pm.SimplePowerlaw27, None),
# Zenith angle in degrees. 0=vertical, 90=horizontal
theta_deg=0.0
)
# Out:
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$

# %%
### Getting the rest of the models for the Z-factor plot

base_model = 'DPMJETIII191'
# config.mceq_db_fname = 'mceq_db_lext_dpm191_v131.h5'
config.enable_default_tracking = False
config.adv_set['fix_dpmjet_neutral_kaons'] = True
mceq = MCEqRun(
    interaction_model=base_model,
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_sibyll = MCEqRun(
    interaction_model='SIBYLL23C',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_epos = MCEqRun(
    interaction_model='eposlhc',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
mceq_qgs = MCEqRun(
    interaction_model='qgsjetii04',
    theta_deg=0.,
    primary_model=(pm.SimplePowerlaw27,None))
# Out:
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): DPMJETIII191
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): SIBYLL23C
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): EPOSLHC
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$
# /home/jp/software/MCEq/MCEq/data/mceq_db_lext_dpm191_v131.h5
# MCEqRun::set_interaction_model(): QGSJETII04
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$

# %%
from references import Honda2006ZFactors
honda_zfac = Honda2006ZFactors(floc='/home/jp/projects/atm_nu/plot_scripts_anatoli/Sanuki_Honda_2006_ZFactors.csv')

# %% [markdown]
# Define variables and angles
# -------------------------

# %%
#Power of energy to scale the flux (the results will be returned as E**mag * flux)
mag = 3

#obtain energy grid (fixed) of the solution for the x-axis of the plots
e_grid = mceq_ddm.e_grid

#Dictionary for results
flux = {}

#Define a zenith angle, counted positively from vertical direction. Theta = 0. means vertical, theta = 90. horizontal
theta = 60.

# %% [markdown]
# ## Creating or loading the original DDM Z-factors

# %%
from MCEq.ddm import DataDrivenModel
from os.path import join

# %%
ddm = DataDrivenModel(
    join(config.data_dir, 'CarbonTargetFits_inclna49K_pp2pC4.npy'))

# %%
#print(ddm)

# %% [markdown]
# Here needs to go the energy of what we have chosen for the extrapolation point

# %%
for prim, sec in ddm.channels:
    if prim != 2212:
        continue
    ddm.clone_datapoint(prim, sec, 158, 2e3)
    ddm.clone_datapoint(prim, sec, 158, 2e4)
    ddm.clone_datapoint(prim, sec, 158, 2e5)
ddm.clone_datapoint(prim, 2212, 158., 31.0)
ddm.clone_datapoint(prim, -2212, 158., 31.0)
ddm.clone_datapoint(prim, 2112, 158., 31.0)

# %%
#print(ddm)

# %%
# Inject DDM in MCEq
mceq_ddm.inject_ddm(ddm)

# %%
secs = [211, -211, 321, -321, 2212, 2112, 310]
#zfac_fname = 'zfac_ddm_original_splitvhe_lepn.pkl'
zfac_fname_original = '/home/jp/projects/atm_nu/plot_scripts_anatoli/zfac_ddm_original_splitvhe.pkl' #This contains the LE stuff
zfac_fname = 'zfac_lib_smart.pkl' # The new one

# %%
if os.path.isfile(zfac_fname):
    zfac_lib = pickle.load(open(zfac_fname, 'rb'))
if os.path.isfile(zfac_fname_original):
    zfac_ddm_original = pickle.load(open(zfac_fname_original,'rb'))

# %% [markdown]
# ## Getting the Z-factors from the fits

# %%
def plotZfac(zfac_ddm_cal_list, 
            plot_other_models = True,
            ylim_scale = 2,
            err_scale = {'pi+':2, 'pi-':5, 'K+':7 , 'K-':10 , 'p':4, 'n':2}):
    ddm_color = "violet"
    ddm_extension = "violet" #"darkgreen"
    for m in [mceq_ddm]:
        m.set_primary_model(pm.SimplePowerlaw27())
    # plot_impy_direct = False
    # plot_other_models = True
    # plot_honda = True
    fs = 12
    secs = [211, -211, 321, -321, 2212, 2112, 310]
    secs_label = ['pi+','pi-','K+','K-','p','n','K0']
    elabels = ['le_','he_','vhe1_','vhe2_','vhe3_']
    pdg2name = {
        211: r"$\pi^+$",
        -211: r"$\pi^-$",
        321: r"K$^+$",
        -321: r"K$^-$",
        2212: r"p",
        -2212: r"$\bar{\rm p}$",
        2112: r"n",
        310: r"K$^0_S$",
        130: r"K$^0_L$",
    }
    particle_labels = {
        211: r"$\pi^+$",
        -211: r"$\pi^-$",
        321: r"K$^+$",
        -321: r"K$^-$",
        2212: r"p+$\bar{\rm p}$",
        2112: r"n+$\bar{\rm n}$",
        310: r"K$^0_S$+K$^0_L$",
    }
    colors = ["#0D589A", "#5DB5D0", "#A9DBB7", "red", "#F24333"]


    def add_zfactor(mceq_obj, prim, sec1, sec2=None):
        if sec2 is not None:
            return mceq_obj.z_factor(prim, sec1, use_cs_scaling=False) + mceq_obj.z_factor(
                prim, sec2, use_cs_scaling=False
            )
        else:
            return mceq_obj.z_factor(prim, sec1, use_cs_scaling=False)




    fig, axes = plt.subplots(2, 4, sharex=True, figsize=(9, 4.7))
    ms = 4
    prim = 2212
    r = [321, -321, -2212]
    #secs = [211, -211, 321, -321, 2212, 2112, 310]
    for i, seci in enumerate(secs):
        ax = axes.flatten()[i]  # [i//3, i%3]

        norm = 1.0  # zair[2]

        if seci == 2212:
            sec2 = -2212
        elif seci == 2112:
            sec2 = -2212
        elif seci == 310:
            sec2 = 130
        else:
            sec2 = None

        # DDM model
        #ddm_zfac = add_zfactor(mceq_ddm, prim, seci, sec2)
        #print(ddm_zfac)
        ax.semilogx(
            mceq_ddm.e_grid,
            add_zfactor(mceq_ddm, prim, seci, sec2),
            c="violet",
            lw=3,
            alpha=0.8,
            label="DDM in MCEq, no tune" if i == 0 else "_nolabel_",
        )
        
        if plot_other_models:
            sel = np.where(mceq.e_grid > 80)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_sibyll, prim, seci, sec2)[sel]/norm,c='k', ls='-', 
                        label='SIBYLL-2.3d' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 5.)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq, prim, seci, sec2)[sel]/norm,c=colors[3],
                        label='DPMJET-III 19.1' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 30.)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_epos, prim, seci, sec2)[sel]/norm,c='blue', 
                        label='EPOS-LHC' if i == 0 else '_nolabel_')
            sel = np.where(mceq.e_grid > 100)
            ax.semilogx(mceq.e_grid[sel], add_zfactor(mceq_qgs, prim, seci, sec2)[sel]/norm,c='darkred', 
                        label='QGSJET-II-04' if i == 0 else '_nolabel_')
        if seci != -2212 and prim == 2212:# and plot_honda:
            ax.semilogx(*honda_zfac.get_data(pdgid=seci),c='gold',ls='-',label='HKKMS' if i == 0 else '_nolabel_')
            
        ax.set_xticks([1.0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6])
        ax.set_ylim(-ax.get_ylim()[1] / 20, ylim_scale * ax.get_ylim()[1])
        ax.set_xlim(10, 1e6)
        if i < 4:
            ax.text(0.8, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        elif i < 6:
            ax.text(0.68, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        else:
            ax.text(0.6, 0.05, particle_labels[seci], transform=ax.transAxes, fontsize=14)
        ax.tick_params(bottom=True, top=True, left=True, right=True, direction="in")

        
        # The points from DDM
        
        for ien, ena in enumerate([31, 158, 2e3, 2e4, 2e5]):
            this_label = elabels[ien] + secs_label[i]
            if this_label in zfac_lib:
                (valj, errj) = zfac_lib[this_label]
                if ena > 200:
                    error_scaling = err_scale[secs_label[i]]
                    #print('Error scale', secs_label[i], error_scaling)
                    thiscolor= ddm_extension
                else:
                    error_scaling = 1
                    thiscolor = ddm_color
                
                # Scale the errj to my estimates
                ax.errorbar(
                    ena,
                    valj,
                    yerr=errj*error_scaling,
                    marker="o",
                    markersize=4,
                    color=thiscolor,
                    label="NA49 & NA61" if i == 3 and ien == 0 else "_nolabel_",
                )    
        
            
                
        for it, tune in enumerate(calibration_results):
            # Open the file
            result = pickle.load(open(calibration_results[tune], 'rb'), encoding='latin1')['params']
            for ien, ena in enumerate([31, 158, 2e3, 2e4, 2e5]):
                this_label = elabels[ien] + secs_label[i]

                if this_label in result:
                    valjcal = (zfac_lib[this_label][0]+
                               zfac_lib[this_label][1]*result[this_label]['value'])
                    errjcal = zfac_lib[this_label][1]*result[this_label]['error']

                    #print(this_label, valjcal, errjcal)
                    ax.errorbar(
                        ena*(1+it/4.),
                        valjcal,
                        yerr=errjcal,
                        marker="o",
                        markersize=4,
                        color="C"+"%i" % it,
                        label= tune if i == 3 and ien == 0 else "_nolabel_",
                        zorder=9
                    )

                    #print(i, ien, i == 3 and ien == 0)
                    

        if i // 4 == 1:
            ax.set_xlabel(r"$E_p$ [GeV]", fontsize=fs - 1)
        elif i == 3:
            ax.set_xlabel(r"$E_p$ [GeV]", fontsize=fs - 1)
        else:
            ax.xaxis.set_ticklabels([])

        if i % 4 == 0:
            ax.set_ylabel(r"$Z_{p,\mathrm{sec}}$", fontsize=fs)


    for ax in axes.flatten():
        ax.tick_params(axis="both", which="major", labelsize=fs - 3)

    axes[-1, -1].set_visible(False)
    axes[-1, 0].set_xticks([1.0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7])

    fig.legend(
        fontsize=fs - 2,
        frameon=False,
        ncol=1,
        bbox_to_anchor=(0.985, 0.48),
        bbox_transform=fig.transFigure,
        title="Proton-air",
    )

    fig.tight_layout(w_pad=-0.05, h_pad=-1)
    # plt.subplots_adjust(top = 0.9)
    plt.savefig("DDM_tune_Zfactors_splitVHE.png", dpi=200)
    return fig
    # plt.savefig('../../figures/zfactors_protons.png', dpi=300)
    # plt.savefig('../../figures/zfactors_protons.pdf')
    # fig.savefig('/Users/mhuber/AtmosphericShowers/Paper_hadronic_Flux_uncertainties/Plots/Zfactors_2212_impy_sibyll_norm.pdf',
    #    bbox_inches="tight")

# %%
my_params = ['scale','GSF_1','GSF_2',
                   'GSF_3','GSF_4',
                   'GSF_5','GSF_6']

my_params = ['le_pi+','le_pi-','le_K+','le_K-',

                  'he_pi+','he_pi-', 'he_K+','he_K-',
                   'he_p','he_n',
                  
                  'vhe1_pi+', 'vhe1_pi-', 
                  
                  'vhe2_pi+', 'vhe2_pi-', 
                  
                  'vhe3_pi+', 'vhe3_pi-', 
                  'vhe3_K+','vhe3_K-',
                   'vhe3_p','vhe3_n',
                  #'scale',

                   'GSF_1','GSF_2',
                   'GSF_3','GSF_4',
                   'GSF_5','GSF_6']
# my_params = ['l3c_align',
#                    'l3c_bfield',
#                    'l3c_eloss',
#                    'l3c_overb',
#                    'l3c_normHor',
#                    'l3c_normVert',
#                    'l3c_pres',
#                    'mn_escale',
#                    'bess_align',
#                    'bess_finres']
nparams = len(my_params)
def resultSummary(calfiles):
    fig = plt.figure(figsize=(10,4))
    chi2_list = np.zeros(len(calfiles))
    cal_names = []
    for ires, fresult in enumerate(calfiles):
        if calfiles[fresult] == '':
            continue
        with open(calfiles[fresult], 'rb') as data_file:
            result = pickle.load(data_file, encoding='latin1')
        cal_names.append(fresult)
        chi2_list[ires] = result['chi2']
        test_params = {}
        values = np.zeros(nparams)
        errors = np.zeros_like(values)
        for iphys, one_phys in enumerate(my_params):
            if one_phys in result['params']:
                values[iphys] = result['params'][one_phys]['value']
                errors[iphys] = result['params'][one_phys]['error']
                
        plt.errorbar(np.arange(len(my_params))+0.1*ires,
                 values, errors, fmt='+', label=fresult)
    _ = plt.xticks(range(nparams), 
                       my_params, rotation='vertical')
    
    plt.legend(loc=0)
    plt.ylim(-4,4)
    
    
    fig = plt.figure(figsize=(10,4))
    plt.plot(np.arange(chi2_list.size),
            chi2_list, 'x')
    _ = plt.xticks(range(chi2_list.size), 
                    cal_names, rotation='vertical')     
    plt.ylabel('Chi2')
    
    return fig
    #plt.ylim(-1,1)

# %%
# All R2 increase the errors of HE K+/- from 1 to 4
calibration_results = {
    #'V15_noScale': '/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_noScale_v2.pkl',
     #'V15_allFree_heK': '/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree.pkl',
    #'V15_noScale_heK': '/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_noScale.pkl',

    #'V15_largeScale':'/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_largeScale.pkl',
         #'PreMuFix': '/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_v2.pkl',
#     'AllExp':'/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_v2_allExp.pkl',
    #'PlusAMS':'/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_v2_noMARS.pkl',
    #'PostMuFix': '/home/jp/projects/atm_nu/ddm_results/prd22_v16_allfree.pkl',
#     'MarsForBess':'/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_v2_swap.pkl',
#     'AMSforBess':'/home/jp/projects/atm_nu/ddm_results/prd22_v15_allfree_v2_swapAMS.pkl',
    #'OldRatios': '/home/jp/projects/atm_nu/ddm_results/prd22_v16_allfree.pkl',
    'Cal1': '/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v17_postPrior.pkl',
    #'CalTight': '/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v17_fixVHE2pi.pkl',
    #'NoDEIS':'/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v17_postPrior_nodeis.pkl'
    'NoVHE2': '/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v18.pkl',
    'Smarter':'/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v19.pkl',
    #'NoMINOS':'/home/jp/projects/atm_nu/ddm_results/prd22_qf2_v18_noMINOS.pkl'
}

# %% [markdown]
# calibration_results = {}

# %% [raw]
# #zfacs = makeZfac(calibration_results)
# fig = plotZfac(calibration_results,
#          plot_other_models = True,
#         ylim_scale=2.,
#         err_scale = {'pi+':2., 'pi-':8, 'K+':8 , 'K-':18 , 'p':8, 'n':3})
# fig.savefig(os.path.join(outdir, 'zfactors_noscale.pdf'))
# resultSummary(calibration_results)

# %%
#zfacs = makeZfac(calibration_results)
fig = plotZfac(calibration_results,
         plot_other_models = True,
        ylim_scale=2.,
        err_scale = {'pi+':3., 'pi-':14, 'K+':12 , 'K-':20 , 'p':8, 'n':3})
fig.savefig(os.path.join(outdir, 'zfactors_noscale.pdf'))
resultSummary(calibration_results)
# Out:
# MCEqRun::set_primary_model(): Primary model set to $E^{-2.7}$

# %% [markdown]
# #### Still need to add a loop to include multiple models in the test

# %%
calibration_results.update({'DDM+GSF':''})

# %%
# Global plot configuration

fs = 16
fs_ticks = 16
alpha_mod = .15
data_marker_config = {'lw':1, 'linestyle':'None', 'alpha':.8, 'markersize':3.}
#colors = ['black', 'blue', 'orange', 'green', 'red', 'grey', 'pink']
#norm = Normalize(0,10)
#s_m = cm.ScalarMappable(cmap=cm.magma, norm=norm)
#s_m.set_array([])
#colors = [s_m.to_rgba(i) for i in range(10)]

# %%
import quickflux2
quickflux = quickflux2.MCEq_fastflux(flux_tables='ddmgsf-v18')
# Out:
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221115_newstyle_smart2.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v18
# Adjusting DEIS name

# %%
def comparePlots(calfiles,
                reference = 'DDM+GSF',
                particle = 'numuflux'):
    #reference = 'CAL_2E'
    #particle = 'numuflux'
    exp = 'cms'
    angle = '0.0000'

    fluxes = []
    errors = []
    keys   = []

    mag=3
    egrid = np.logspace(-1,5.99)


    # Load all the fluxes
    refindex = None
    for ires, fresult in enumerate(calfiles):
        keys.append(fresult)
        if reference == fresult:
            refindex = ires
            
        #print(keys[-1])

        if calfiles[fresult] == '':
            # Use default spline
            fluxes.append(quickflux.get_flux_new(egrid, exp, angle, particle, use_calibration = False))
            errors.append(quickflux.get_error_new(egrid, exp, angle, particle, use_calibration = False))

        else:
            print(fresult)
            with open(calfiles[fresult], 'rb') as data_file:
                result = pickle.load(data_file, encoding='latin1')

            # Splines path
            splines_path = result['flux_tables']
#             splines_path = os.path.join(mufit_config.jacobians_dir,
#                                         mufit_config.jacobians[result['flux_tables']])

            # Set up the quickflux calibration file and 
            #print(keys[ires], calfiles[fresult], splines_path)
            
            quickflux.set_mufit_spl(splines_path)
            quickflux.set_calibration_file(calfiles[fresult])
           # print(quickflux._calibration_file)
            #quickflux.load_splines()
            
            
            fluxes.append(deepcopy(quickflux.get_flux_new(egrid, exp, angle, 
                                                 particle, 
                                                 use_calibration=True)))
            
            errors.append(quickflux.get_error_new(egrid, exp, angle, 
                                                  particle, 
                                                  use_calibration=True))
            
            #print(quickflux.cal_values)
    ## Plotting all the fluxes here
    
    ## TOP plot, the fluxes
    fig, axes = plt.subplots(
        3, 1, figsize=(5.5, 8.5), sharex=True, gridspec_kw={"height_ratios": (1, 1,1)}
    )
    ax = axes[0]

    #ax.set_ylabel(r"($E$/GeV)$^3~\Phi_{\nu_\mu}$ (GeV cm$^{2}$ s sr)$^{-1}$", fontsize=fs - 4)
    ax.set_ylabel(particle)

    #print(keys)
    for ires in range(len(keys)):

        ax.fill_between(egrid, fluxes[ires] + errors[ires], fluxes[ires] - errors[ires], 
                        facecolor="C"+"%i" % ires, alpha=alpha_mod, label=keys[ires])
        ax.plot(egrid, fluxes[ires], ls="solid", color="C"+"%i" % ires, 
                alpha=0.8)

    ## Calibrated DDM+GSF
    #ax.fill_between(egrid, flux_cal + err_cal, flux_cal - err_cal, 
    #                facecolor="r", alpha=alpha_mod)
    #ax.plot(egrid, flux_cal, ls="-.", color="r", alpha=0.8)

    ax.set_xscale("log")

    if not 'ratio' in particle:
        ax.set_yscale("log")
        ax.set_ylim(2e-4, 1.5e-1)


    ax.set_xlim(0.1, 9e5)
    ax.tick_params(
        axis="both",
        which="both",
        right=True,
        top=True,
        direction="inout",
        labelsize=fs_ticks - 5,
    )
    
    
    
    # ## MIDDLE figure - ratios    
    ax = axes[1]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, fluxes[ires]/fluxes[refindex],
                   c="C"+"%i" % ires, ls='-')
        ax.fill_between(egrid,
                        (fluxes[ires]+errors[ires])/fluxes[refindex],
                        (fluxes[ires]-errors[ires])/fluxes[refindex],
                       facecolor = "C"+"%i" % ires,
                       alpha=alpha_mod, label=keys[ires])

    ax.set_ylabel("Model/"+keys[refindex])
    #ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)
    ax.set_ylim(0.8, 1.2)
    
    
    ax = axes[2]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, errors[ires]/fluxes[ires],
                   c="C"+"%i" % ires, ls='-', label=keys[ires])

    ax.set_ylabel("Model error")
    ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)    
    plt.tight_layout(h_pad=-0.5)
    plt.legend(loc=0)

# %%
calibration_results.update({'DDM+GSF':''})
myref = 'DDM+GSF'

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'muflux')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoVHE2
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221115_newstyle_smart2.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v18
# NoMINOS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221115_newstyle_smart2.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v18

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'muratio')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'numuflux')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'nueflux')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'numuratio')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'nueratio')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
comparePlots(calibration_results, 
             reference=myref,
            particle = 'flavorratio')
# Out:
# Cal1
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# CalTight
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17
# NoDEIS
# /home/jp/projects/atm_nu/mceq_tysak/muon_fit/modules/resources/DDM_splines_20221114_newstyle_smart.pkl
# Excluded params removed from known_params.
# No calibration file for ddmgsf-v17

# %%
def comparePlots2(calfiles,
                reference = 'DDM+GSF',):
    #reference = 'CAL_2E'
    #particle = 'numuflux'
    exp = 'average'
    angle = 'average'

    fluxes = []
    fluxes2 = []

    errors = []
    keys   = []

    mag=3
    egrid = np.logspace(-1,5.99)


    # Load all the fluxes
    refindex = None
    for ires, fresult in enumerate(calfiles):
        keys.append(fresult)
        if reference == fresult:
            refindex = ires
            
        #print(keys[-1])

        if calfiles[fresult] == '':
            # Use default spline
            fluxes.append(quickflux.get_flux_new(egrid, exp, angle, 'numuflux', use_calibration = False)/
                          quickflux.get_flux_new(egrid, exp, angle, 'nueflux', use_calibration = False))
            fluxes2.append(quickflux.get_flux_new(egrid, exp, angle, 'flavorratio', use_calibration = False))           
            errors.append(quickflux.get_error_new(egrid, exp, angle, 'numuflux', use_calibration = False))

        else:
            print(fresult)
            with open(calfiles[fresult], 'rb') as data_file:
                result = pickle.load(data_file, encoding='latin1')

            # Splines path
            splines_path = os.path.join(mufit_config.jacobians_dir,
                                        mufit_config.jacobians[result['flux_tables']])

            # Set up the quickflux calibration file and 
            #print(keys[ires], calfiles[fresult], splines_path)
            quickflux.set_calibration_file(calfiles[fresult])
            quickflux.set_mufit_spl(splines_path)
           # print(quickflux._calibration_file)
            #quickflux.load_splines()
            
            
            fluxes.append(deepcopy(quickflux.get_flux_new(egrid, exp, angle, 
                                                 'numuflux', 
                                                 use_calibration=True)/
                                  quickflux.get_flux_new(egrid, exp, angle, 
                                                 'nueflux', 
                                                 use_calibration=True)))
            fluxes2.append(deepcopy(quickflux.get_flux_new(egrid, exp, angle, 
                                     'flavorratio', 
                                     use_calibration=True)))
            
            errors.append(quickflux.get_error_new(egrid, exp, angle, 
                                                  'numuflux', 
                                                  use_calibration=True))
            
            #print(quickflux.cal_values)
    ## Plotting all the fluxes here
    
    ## TOP plot, the fluxes
    fig, axes = plt.subplots(
        3, 1, figsize=(5.5, 8.5), sharex=True, gridspec_kw={"height_ratios": (1, 1,1)}
    )
    ax = axes[0]

    #ax.set_ylabel(r"($E$/GeV)$^3~\Phi_{\nu_\mu}$ (GeV cm$^{2}$ s sr)$^{-1}$", fontsize=fs - 4)
    ax.set_ylabel('flavor ratio')

    #print(keys)
    for ires in range(len(keys)):

        ax.fill_between(egrid, fluxes[ires] + errors[ires], fluxes[ires] - errors[ires], 
                        facecolor="C"+"%i" % ires, alpha=alpha_mod, label=keys[ires])
        ax.plot(egrid, fluxes[ires], ls="solid", color="C"+"%i" % ires, 
                alpha=0.8)
        ax.plot(egrid, fluxes2[ires], ls="--", color="C"+"%i" % ires, 
                alpha=0.8)

    ## Calibrated DDM+GSF
    #ax.fill_between(egrid, flux_cal + err_cal, flux_cal - err_cal, 
    #                facecolor="r", alpha=alpha_mod)
    #ax.plot(egrid, flux_cal, ls="-.", color="r", alpha=0.8)

    ax.set_xscale("log")



    ax.set_xlim(0.1, 9e5)
    ax.tick_params(
        axis="both",
        which="both",
        right=True,
        top=True,
        direction="inout",
        labelsize=fs_ticks - 5,
    )
    
    
    
    # ## MIDDLE figure - ratios    
    ax = axes[1]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, fluxes[ires]/fluxes[refindex],
                   c="C"+"%i" % ires, ls='-')
        ax.fill_between(egrid,
                        (fluxes[ires]+errors[ires])/fluxes[refindex],
                        (fluxes[ires]-errors[ires])/fluxes[refindex],
                       facecolor = "C"+"%i" % ires,
                       alpha=alpha_mod, label=keys[ires])

    ax.set_ylabel("Model/"+keys[refindex])
    #ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)
    ax.set_ylim(0.8, 1.2)
    
    
    ax = axes[2]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, errors[ires]/fluxes[ires],
                   c="C"+"%i" % ires, ls='-', label=keys[ires])

    ax.set_ylabel("Model error")
    ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)    
    plt.tight_layout(h_pad=-0.5)
    plt.legend(loc=0)

# %%
comparePlots2(calibration_results, 
             reference=myref)
# Out:
# Cal1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-b39a8e5ffce3> in <module>
#       1 comparePlots2(calibration_results,
# ----> 2              reference=myref)
#
# <ipython-input-35-3d8b295f2465> in comparePlots2(calfiles, reference)
#      44             #print(keys[ires], calfiles[fresult], splines_path)
#      45             quickflux.set_calibration_file(calfiles[fresult])
# ---> 46             quickflux.set_mufit_spl(splines_path)
#      47            # print(quickflux._calibration_file)
#      48             #quickflux.load_splines()
#
# ~/projects/atm_nu/mceq_tysak/muon_fit/modules/quickflux2.py in set_mufit_spl(self, fname)
#      82         # Changed to use identifiers instead of full filename
#      83         path = pathlib.Path(base_path, "resources",
# ---> 84                             mufit_config.jacobians[fname])
#      85         if not path.is_file():
#      86             raise IOError("Spline file "+path+" not found.")
#
# KeyError: '/home/jp/projects/atm_nu/jacobians/DDM_splines_20221114_newstyle_smart.pkl'

# %%
def upHorRatio(calfiles,
                reference = 'DDM+GSF',
                particle = 'numuflux'):
    #reference = 'CAL_2E'
    #particle = 'numuflux'
    exp = 'IceCube'#'average'

    fluxes = []
    errors = []
    keys   = []

    mag=3
    egrid = np.logspace(-1,5.99)
    
    icangles = list(quickflux.fl_spl[exp].keys())
    

    # Load all the fluxes
    refindex = None
    for ires, fresult in enumerate(calfiles):
        keys.append(fresult)
        if reference == fresult:
            refindex = ires
            
        print('Starting with', fresult)
        
        
        full_flux = np.zeros([len(egrid), len(icangles)])
        flux_hor = np.zeros_like(egrid)
        error_hor2 = np.zeros_like(egrid)
        hor_bins = 0
        
        flux_up = np.zeros_like(egrid)
        error_up2 = np.zeros_like(egrid)
        up_bins = 0
        
                

        if calfiles[fresult] != '':
            # Setting up the results
            with open(calfiles[fresult], 'rb') as data_file:
                result = pickle.load(data_file, encoding='latin1')

            # Splines path
            splines_path = os.path.join(mufit_config.jacobians_dir,
                                        mufit_config.jacobians[result['flux_tables']])

            # Set up the quickflux calibration file and 
            #print(keys[ires], calfiles[fresult], splines_path)
            quickflux.set_calibration_file(calfiles[fresult])
            quickflux.set_mufit_spl(splines_path)
            
            use_calibration = True
            
        else:
            
            use_calibration = False
            
        # Use default spline, loop over angles
        for index in range(len(icangles)):
            costheta = np.cos(np.deg2rad(np.float(icangles[index])))
            #print(costheta)
            # Horizontal
            
            #full_flux[:,index] = quickflux.get_flux_new(egrid, exp, icangles[index], particle,
            #                                      use_calibration = use_calibration)
            if np.abs(costheta)<0.3:
                flux_hor += quickflux.get_flux_new(egrid, exp, icangles[index], particle,
                                                  use_calibration = use_calibration)
                error_hor2 += quickflux.get_error_new(egrid, exp,  icangles[index], particle,
                                                      use_calibration = use_calibration)**2
                hor_bins += 1
                #print('Horizontal', icangles[index], costheta, flux_hor)
            # Up-going
            elif costheta>0.5:
                flux_up += quickflux.get_flux_new(egrid, exp, icangles[index], particle,
                                                  use_calibration = use_calibration)
                error_up2 += quickflux.get_error_new(egrid, exp,  icangles[index], particle,
                                                     use_calibration = use_calibration)**2
                up_bins += 1
                #print('Up', icangles[index], costheta)

        # Now the "flux" can be appended
        uphor_ratio = (flux_up/flux_hor)*(hor_bins/up_bins)
        fluxes.append(uphor_ratio)
        errors.append(np.sqrt(error_hor2/flux_hor**2 + error_up2/flux_up**2)*uphor_ratio)
           
    
    
    ## TOP plot, the fluxes
    fig, axes = plt.subplots(
        3, 1, figsize=(5.5, 8.5), sharex=True, gridspec_kw={"height_ratios": (1, 1,1)}
    )
    ax = axes[0]

    #ax.set_ylabel(r"($E$/GeV)$^3~\Phi_{\nu_\mu}$ (GeV cm$^{2}$ s sr)$^{-1}$", fontsize=fs - 4)
    ax.set_ylabel('Up/Hor flux')

    #print(keys)
    for ires in range(len(keys)):

        ax.fill_between(egrid, fluxes[ires] + errors[ires], fluxes[ires] - errors[ires], 
                        facecolor="C"+"%i" % ires, alpha=alpha_mod, label=keys[ires])
        ax.plot(egrid, fluxes[ires], ls="solid", color="C"+"%i" % ires, 
                alpha=0.8)

    ## Calibrated DDM+GSF
    #ax.fill_between(egrid, flux_cal + err_cal, flux_cal - err_cal, 
    #                facecolor="r", alpha=alpha_mod)
    #ax.plot(egrid, flux_cal, ls="-.", color="r", alpha=0.8)

    ax.set_xscale("log")
    #ax.set_yscale("log")

    ax.set_xlim(1, 9e5)
    ax.tick_params(
        axis="both",
        which="both",
        right=True,
        top=True,
        direction="inout",
        labelsize=fs_ticks - 5,
    )
    
    
    
    # ## MIDDLE figure - ratios    
    ax = axes[1]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, fluxes[ires]/fluxes[refindex],
                   c="C"+"%i" % ires, ls='-')
        ax.fill_between(egrid,
                        (fluxes[ires]+errors[ires])/fluxes[refindex],
                        (fluxes[ires]-errors[ires])/fluxes[refindex],
                       facecolor = "C"+"%i" % ires,
                       alpha=alpha_mod, label=keys[ires])

    ax.set_ylabel("Model/"+keys[refindex])
    #ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)
    ax.set_ylim(0.8, 1.2)
    
    
    ax = axes[2]
    for ires in range(len(keys)):
        #print(fluxes[ires]/fluxes[refindex])
        ax.semilogx(egrid, errors[ires]/fluxes[ires],
                   c="C"+"%i" % ires, ls='-', label=keys[ires])

    ax.set_ylabel("Model error")
    ax.set_xlabel(r"$E_{\nu_{\mu}}$ (GeV)", fontsize=fs - 4)    
    plt.tight_layout(h_pad=-0.5)
    plt.legend(loc=0)

    return full_flux

# %%
#myref = 'DDM+GSF'
full_flux = upHorRatio(calibration_results, 
             reference=myref,
            particle = 'numuflux')
